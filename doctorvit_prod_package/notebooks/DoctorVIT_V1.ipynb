# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install python-dotenv

import os
from dotenv import load_dotenv

env_path = '/content/drive/MyDrive/neuroweave.env'

if not os.path.isfile(env_path):
    raise FileNotFoundError(f"Couldn’t find neuroweave.env at:\n  {env_path}\n"
                            "Please confirm the path by inspecting the ls output above.")
load_dotenv(env_path, override=True)

github_user  = os.environ.get('GITHUB_USER')
github_token = os.environ.get('GITHUB_TOKEN')

if not (github_user and github_token):
    raise RuntimeError("Loaded env file, but variables are still missing.")
# Out:
# Mounted at /content/drive
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.1.1)

# %%
# !pip install git+https://${GITHUB_USER}:${GITHUB_TOKEN}@github.com/ajaviaad/neuronmix.git@main
# Out:
# Collecting git+https://ajaviaad:****@github.com/ajaviaad/neuronmix.git@main
#   Cloning https://ajaviaad:****@github.com/ajaviaad/neuronmix.git (to revision main) to /tmp/pip-req-build-pucp_eyl
#   Running command git clone --filter=blob:none --quiet 'https://ajaviaad:****@github.com/ajaviaad/neuronmix.git' /tmp/pip-req-build-pucp_eyl
#   Resolved https://ajaviaad:****@github.com/ajaviaad/neuronmix.git to commit c81b9bb3ba976bc438d0b2c41d0714f5b1ed9523
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from neuronmix==0.1.3) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->neuronmix==0.1.3) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->neuronmix==0.1.3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->neuronmix==0.1.3) (3.0.2)
# Building wheels for collected packages: neuronmix
#   Building wheel for neuronmix (setup.py) ... done
#   Created wheel for neuronmix: filename=neuronmix-0.1.3-py3-none-any.whl size=5890 sha256=505145089fceb8183168a25a2274a05869f53b0d830a3e539f8fe7e2be405c9b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ma6dfw_u/wheels/c6/35/88/9c40df155694153134ca51840a58beb9843822598137f8a34c
# Successfully built neuronmix
# Installing collected packages: neuronmix
# Successfully installed neuronmix-0.1.3

# %%
model_path = "/content/drive/MyDrive/neuroweave"

# %%
# !unzip /content/drive/MyDrive/transformers.zip -d /content/custom_transformers
import sys
sys.path.insert(0, "/content/custom_transformers")
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/_toctree.yml
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/accelerate.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/add_new_model.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/attention.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/autoclass_tutorial.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/bertology.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/big_models.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/chat_templating.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/community.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/create_a_model.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/custom_models.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/fast_tokenizers.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/generation_strategies.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/glossary.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/hpo_train.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/index.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/installation.md
#    creating: /content/custom_transformers/transformers-main/docs/source/ja/internal/
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/internal/audio_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/internal/file_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/internal/generation_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/internal/image_processing_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/internal/modeling_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/internal/pipelines_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/internal/time_series_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/internal/tokenization_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/internal/trainer_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/llm_tutorial.md
#    creating: /content/custom_transformers/transformers-main/docs/source/ja/main_classes/
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/main_classes/callback.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/main_classes/configuration.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/main_classes/data_collator.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/main_classes/deepspeed.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/main_classes/feature_extractor.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/main_classes/image_processor.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/main_classes/keras_callbacks.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/main_classes/logging.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/main_classes/model.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/main_classes/onnx.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/main_classes/optimizer_schedules.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/main_classes/output.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/main_classes/pipelines.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/main_classes/processors.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/main_classes/quantization.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/main_classes/text_generation.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/main_classes/tokenizer.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/main_classes/trainer.md
#    creating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/albert.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/align.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/altclip.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/audio-spectrogram-transformer.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/auto.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/autoformer.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/bark.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/bart.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/barthez.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/bartpho.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/beit.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/bert-generation.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/bert-japanese.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/bert.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/bertweet.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/big_bird.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/bigbird_pegasus.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/biogpt.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/bit.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/blenderbot-small.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/blenderbot.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/blip-2.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/blip.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/bloom.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/bort.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/bridgetower.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/bros.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/byt5.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/camembert.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/canine.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/chinese_clip.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/clap.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/clip.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/clipseg.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/clvp.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/code_llama.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/codegen.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/conditional_detr.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/convbert.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/convnext.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/convnextv2.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/cpm.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/cpmant.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/ctrl.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/cvt.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/data2vec.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/deberta-v2.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/deberta.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/decision_transformer.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/deformable_detr.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/deit.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/deplot.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/deta.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/detr.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/dialogpt.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_doc/dinat.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_memory_anatomy.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_sharing.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/model_summary.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/multilingual.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/pad_truncation.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/peft.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/perf_hardware.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/perf_infer_cpu.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/perf_infer_gpu_many.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/perf_infer_gpu_one.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/perf_infer_special.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/perf_torch_compile.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/perf_train_cpu.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/perf_train_cpu_many.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/perf_train_gpu_many.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/perf_train_gpu_one.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/perf_train_special.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/perf_train_tpu.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/perf_train_tpu_tf.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/performance.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/perplexity.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/philosophy.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/pipeline_tutorial.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/pipeline_webserver.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/pr_checks.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/preprocessing.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/quicktour.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/run_scripts.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/serialization.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/task_summary.md
#    creating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/asr.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/audio_classification.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/document_question_answering.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/idefics.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/image_captioning.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/image_classification.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/image_to_image.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/knowledge_distillation_for_image_classification.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/language_modeling.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/masked_language_modeling.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/monocular_depth_estimation.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/multiple_choice.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/object_detection.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/prompting.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/question_answering.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/semantic_segmentation.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/sequence_classification.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/summarization.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/text-to-speech.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/token_classification.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/translation.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/video_classification.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/visual_question_answering.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/zero_shot_image_classification.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks/zero_shot_object_detection.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tasks_explained.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/testing.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tf_xla.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tflite.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/tokenizer_summary.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/torchscript.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/training.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ja/troubleshooting.md
#    creating: /content/custom_transformers/transformers-main/docs/source/ko/
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/_config.py
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/_toctree.yml
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/accelerate.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/add_new_model.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/add_new_pipeline.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/attention.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/autoclass_tutorial.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/bertology.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/big_models.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/chat_templating.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/community.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/contributing.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/conversations.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/create_a_model.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/custom_models.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/debugging.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/deepspeed.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/fast_tokenizers.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/fsdp.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/generation_strategies.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/gguf.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/gpu_selection.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/hpo_train.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/in_translation.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/index.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/installation.md
#    creating: /content/custom_transformers/transformers-main/docs/source/ko/internal/
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/internal/audio_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/internal/file_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/internal/generation_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/internal/image_processing_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/internal/modeling_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/internal/pipelines_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/internal/time_series_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/internal/tokenization_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/internal/trainer_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/llm_optims.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/llm_tutorial.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/llm_tutorial_optimization.md
#    creating: /content/custom_transformers/transformers-main/docs/source/ko/main_classes/
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/main_classes/callback.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/main_classes/configuration.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/main_classes/data_collator.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/main_classes/executorch.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/main_classes/feature_extractor.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/main_classes/keras_callbacks.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/main_classes/logging.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/main_classes/model.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/main_classes/onnx.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/main_classes/output.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/main_classes/quantization.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/main_classes/text_generation.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/main_classes/trainer.md
#    creating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/altclip.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/auto.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/autoformer.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/bart.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/barthez.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/bartpho.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/bert-japanese.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/bert.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/bertweet.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/biogpt.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/blip-2.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/blip.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/chameleon.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/clip.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/codegen.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/cohere.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/convbert.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/dbrx.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/deberta-v2.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/deberta.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/electra.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/encoder-decoder.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/esm.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/gemma.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/gemma2.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/gpt_neox_japanese.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/graphormer.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/informer.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/llama.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/llama2.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/llama3.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/mamba.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/mamba2.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/marian.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/mistral.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/openai-gpt.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/paligemma.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/patchtsmixer.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/patchtst.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/qwen2_vl.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/rag.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/roberta.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/siglip.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/swin.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/swin2sr.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/swinv2.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/time_series_transformer.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/timesformer.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/trajectory_transformer.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/vit.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/vivit.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_doc/whisper.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_memory_anatomy.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_sharing.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/model_summary.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/modular_transformers.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/multilingual.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/pad_truncation.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/peft.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/perf_hardware.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/perf_infer_cpu.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/perf_infer_gpu_one.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/perf_train_cpu.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/perf_train_cpu_many.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/perf_train_gpu_many.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/perf_train_special.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/perf_train_tpu_tf.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/performance.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/perplexity.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/philosophy.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/pipeline_tutorial.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/pipeline_webserver.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/pr_checks.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/preprocessing.md
#    creating: /content/custom_transformers/transformers-main/docs/source/ko/quantization/
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/quantization/awq.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/quantization/bitsandbytes.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/quantization/eetq.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/quantization/gptq.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/quantization/quanto.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/quicktour.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/run_scripts.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/sagemaker.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/serialization.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/serving.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/task_summary.md
#    creating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/asr.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/audio_classification.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/document_question_answering.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/idefics.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/image_captioning.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/image_classification.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/image_feature_extraction.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/image_to_image.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/keypoint_detection.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/knowledge_distillation_for_image_classification.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/language_modeling.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/mask_generation.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/masked_language_modeling.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/monocular_depth_estimation.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/multiple_choice.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/object_detection.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/prompting.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/question_answering.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/semantic_segmentation.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/sequence_classification.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/summarization.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/token_classification.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/translation.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/video_classification.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/visual_question_answering.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/zero_shot_image_classification.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks/zero_shot_object_detection.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tasks_explained.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/testing.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tf_xla.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tflite.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/tokenizer_summary.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/torchscript.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/trainer.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/training.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/ko/troubleshooting.md
#    creating: /content/custom_transformers/transformers-main/docs/source/ms/
#   inflating: /content/custom_transformers/transformers-main/docs/source/ms/_toctree.yml
#   inflating: /content/custom_transformers/transformers-main/docs/source/ms/index.md
#    creating: /content/custom_transformers/transformers-main/docs/source/pt/
#   inflating: /content/custom_transformers/transformers-main/docs/source/pt/_config.py
#   inflating: /content/custom_transformers/transformers-main/docs/source/pt/_toctree.yml
#   inflating: /content/custom_transformers/transformers-main/docs/source/pt/accelerate.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/pt/converting_tensorflow_models.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/pt/create_a_model.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/pt/custom_models.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/pt/fast_tokenizers.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/pt/index.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/pt/installation.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/pt/multilingual.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/pt/pipeline_tutorial.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/pt/quicktour.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/pt/run_scripts.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/pt/serialization.md
#    creating: /content/custom_transformers/transformers-main/docs/source/pt/tasks/
#   inflating: /content/custom_transformers/transformers-main/docs/source/pt/tasks/sequence_classification.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/pt/tasks/token_classification.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/pt/training.md
#    creating: /content/custom_transformers/transformers-main/docs/source/te/
#   inflating: /content/custom_transformers/transformers-main/docs/source/te/_toctree.yml
#   inflating: /content/custom_transformers/transformers-main/docs/source/te/index.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/te/quicktour.md
#    creating: /content/custom_transformers/transformers-main/docs/source/tr/
#   inflating: /content/custom_transformers/transformers-main/docs/source/tr/_toctree.yml
#   inflating: /content/custom_transformers/transformers-main/docs/source/tr/index.md
#    creating: /content/custom_transformers/transformers-main/docs/source/zh/
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/_toctree.yml
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/accelerate.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/add_new_pipeline.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/attention.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/autoclass_tutorial.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/bertology.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/big_models.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/chat_templating.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/community.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/contributing.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/create_a_model.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/custom_models.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/debugging.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/fast_tokenizers.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/fsdp.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/gguf.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/hpo_train.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/index.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/installation.md
#    creating: /content/custom_transformers/transformers-main/docs/source/zh/internal/
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/internal/audio_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/internal/file_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/internal/generation_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/internal/image_processing_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/internal/modeling_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/internal/pipelines_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/internal/time_series_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/internal/tokenization_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/internal/trainer_utils.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/llm_tutorial.md
#    creating: /content/custom_transformers/transformers-main/docs/source/zh/main_classes/
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/main_classes/callback.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/main_classes/configuration.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/main_classes/data_collator.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/main_classes/deepspeed.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/main_classes/feature_extractor.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/main_classes/image_processor.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/main_classes/keras_callbacks.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/main_classes/logging.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/main_classes/model.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/main_classes/onnx.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/main_classes/optimizer_schedules.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/main_classes/output.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/main_classes/pipelines.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/main_classes/processors.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/main_classes/quantization.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/main_classes/text_generation.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/main_classes/tokenizer.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/main_classes/trainer.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/model_sharing.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/multilingual.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/peft.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/perf_hardware.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/perf_infer_gpu_multi.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/perf_torch_compile.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/perf_train_cpu.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/perf_train_special.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/performance.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/philosophy.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/pipeline_tutorial.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/preprocessing.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/quicktour.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/run_scripts.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/serialization.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/task_summary.md
#    creating: /content/custom_transformers/transformers-main/docs/source/zh/tasks/
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/tasks/asr.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/tf_xla.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/tflite.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/tiktoken.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/tokenizer_summary.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/torchscript.md
#   inflating: /content/custom_transformers/transformers-main/docs/source/zh/training.md
#    creating: /content/custom_transformers/transformers-main/examples/
#   inflating: /content/custom_transformers/transformers-main/examples/README.md
#    creating: /content/custom_transformers/transformers-main/examples/flax/
#   inflating: /content/custom_transformers/transformers-main/examples/flax/README.md
#   inflating: /content/custom_transformers/transformers-main/examples/flax/_tests_requirements.txt
#   inflating: /content/custom_transformers/transformers-main/examples/flax/conftest.py
#    creating: /content/custom_transformers/transformers-main/examples/flax/image-captioning/
#   inflating: /content/custom_transformers/transformers-main/examples/flax/image-captioning/README.md
#   inflating: /content/custom_transformers/transformers-main/examples/flax/image-captioning/create_model_from_encoder_decoder_models.py
#   inflating: /content/custom_transformers/transformers-main/examples/flax/image-captioning/run_image_captioning_flax.py
#    creating: /content/custom_transformers/transformers-main/examples/flax/language-modeling/
#   inflating: /content/custom_transformers/transformers-main/examples/flax/language-modeling/README.md
#   inflating: /content/custom_transformers/transformers-main/examples/flax/language-modeling/requirements.txt
#   inflating: /content/custom_transformers/transformers-main/examples/flax/language-modeling/run_bart_dlm_flax.py
#   inflating: /content/custom_transformers/transformers-main/examples/flax/language-modeling/run_bert_flax.py
#   inflating: /content/custom_transformers/transformers-main/examples/flax/language-modeling/run_clm_flax.py
#   inflating: /content/custom_transformers/transformers-main/examples/flax/language-modeling/run_mlm_flax.py
#   inflating: /content/custom_transformers/transformers-main/examples/flax/language-modeling/run_t5_mlm_flax.py
#   inflating: /content/custom_transformers/transformers-main/examples/flax/language-modeling/t5_tokenizer_model.py
#    creating: /content/custom_transformers/transformers-main/examples/flax/question-answering/
#   inflating: /content/custom_transformers/transformers-main/examples/flax/question-answering/README.md
#   inflating: /content/custom_transformers/transformers-main/examples/flax/question-answering/requirements.txt
#   inflating: /content/custom_transformers/transformers-main/examples/flax/question-answering/run_qa.py
#   inflating: /content/custom_transformers/transformers-main/examples/flax/question-answering/utils_qa.py
#    creating: /content/custom_transformers/transformers-main/examples/flax/speech-recognition/
#   inflating: /content/custom_transformers/transformers-main/examples/flax/speech-recognition/README.md
#   inflating: /content/custom_transformers/transformers-main/examples/flax/speech-recognition/requirements.txt
#   inflating: /content/custom_transformers/transformers-main/examples/flax/speech-recognition/run_flax_speech_recognition_seq2seq.py
#    creating: /content/custom_transformers/transformers-main/examples/flax/summarization/
#   inflating: /content/custom_transformers/transformers-main/examples/flax/summarization/README.md
#   inflating: /content/custom_transformers/transformers-main/examples/flax/summarization/requirements.txt
#   inflating: /content/custom_transformers/transformers-main/examples/flax/summarization/run_summarization_flax.py
#   inflating: /content/custom_transformers/transformers-main/examples/flax/test_flax_examples.py
#    creating: /content/custom_transformers/transformers-main/examples/flax/text-classification/
#   inflating: /content/custom_transformers/transformers-main/examples/flax/text-classification/README.md
#   inflating: /content/custom_transformers/transformers-main/examples/flax/text-classification/requirements.txt
#   inflating: /content/custom_transformers/transformers-main/examples/flax/text-classification/run_flax_glue.py
#    creating: /content/custom_transformers/transformers-main/examples/flax/token-classification/
#   inflating: /content/custom_transformers/transformers-main/examples/flax/token-classification/README.md
# ...
#  extracting: /content/custom_transformers/transformers-main/tests/quantization/vptq_integration/__init__.py
#   inflating: /content/custom_transformers/transformers-main/tests/quantization/vptq_integration/test_vptq.py
#    creating: /content/custom_transformers/transformers-main/tests/repo_utils/
#    creating: /content/custom_transformers/transformers-main/tests/repo_utils/modular/
#   inflating: /content/custom_transformers/transformers-main/tests/repo_utils/modular/test_conversion_order.py
#   inflating: /content/custom_transformers/transformers-main/tests/repo_utils/test_check_copies.py
#   inflating: /content/custom_transformers/transformers-main/tests/repo_utils/test_check_docstrings.py
#   inflating: /content/custom_transformers/transformers-main/tests/repo_utils/test_get_test_info.py
#   inflating: /content/custom_transformers/transformers-main/tests/repo_utils/test_tests_fetcher.py
#    creating: /content/custom_transformers/transformers-main/tests/sagemaker/
#   inflating: /content/custom_transformers/transformers-main/tests/sagemaker/README.md
#   inflating: /content/custom_transformers/transformers-main/tests/sagemaker/__init__.py
#   inflating: /content/custom_transformers/transformers-main/tests/sagemaker/conftest.py
#    creating: /content/custom_transformers/transformers-main/tests/sagemaker/scripts/
#    creating: /content/custom_transformers/transformers-main/tests/sagemaker/scripts/pytorch/
#   inflating: /content/custom_transformers/transformers-main/tests/sagemaker/scripts/pytorch/requirements.txt
#   inflating: /content/custom_transformers/transformers-main/tests/sagemaker/scripts/pytorch/run_ddp.py
#   inflating: /content/custom_transformers/transformers-main/tests/sagemaker/scripts/pytorch/run_glue_model_parallelism.py
#    creating: /content/custom_transformers/transformers-main/tests/sagemaker/scripts/tensorflow/
#   inflating: /content/custom_transformers/transformers-main/tests/sagemaker/scripts/tensorflow/requirements.txt
#   inflating: /content/custom_transformers/transformers-main/tests/sagemaker/scripts/tensorflow/run_tf.py
#   inflating: /content/custom_transformers/transformers-main/tests/sagemaker/scripts/tensorflow/run_tf_dist.py
#   inflating: /content/custom_transformers/transformers-main/tests/sagemaker/test_multi_node_data_parallel.py
#   inflating: /content/custom_transformers/transformers-main/tests/sagemaker/test_multi_node_model_parallel.py
#   inflating: /content/custom_transformers/transformers-main/tests/sagemaker/test_single_node_gpu.py
#    creating: /content/custom_transformers/transformers-main/tests/tensor_parallel/
#   inflating: /content/custom_transformers/transformers-main/tests/tensor_parallel/test_tensor_parallel.py
#   inflating: /content/custom_transformers/transformers-main/tests/test_backbone_common.py
#   inflating: /content/custom_transformers/transformers-main/tests/test_configuration_common.py
#   inflating: /content/custom_transformers/transformers-main/tests/test_feature_extraction_common.py
#   inflating: /content/custom_transformers/transformers-main/tests/test_image_processing_common.py
#   inflating: /content/custom_transformers/transformers-main/tests/test_image_transforms.py
#   inflating: /content/custom_transformers/transformers-main/tests/test_modeling_common.py
#   inflating: /content/custom_transformers/transformers-main/tests/test_modeling_flax_common.py
#   inflating: /content/custom_transformers/transformers-main/tests/test_modeling_tf_common.py
#   inflating: /content/custom_transformers/transformers-main/tests/test_pipeline_mixin.py
#   inflating: /content/custom_transformers/transformers-main/tests/test_processing_common.py
#   inflating: /content/custom_transformers/transformers-main/tests/test_sequence_feature_extraction_common.py
#   inflating: /content/custom_transformers/transformers-main/tests/test_tokenization_common.py
#   inflating: /content/custom_transformers/transformers-main/tests/test_training_args.py
#    creating: /content/custom_transformers/transformers-main/tests/tokenization/
#  extracting: /content/custom_transformers/transformers-main/tests/tokenization/__init__.py
#   inflating: /content/custom_transformers/transformers-main/tests/tokenization/test_tokenization_fast.py
#   inflating: /content/custom_transformers/transformers-main/tests/tokenization/test_tokenization_utils.py
#    creating: /content/custom_transformers/transformers-main/tests/trainer/
#  extracting: /content/custom_transformers/transformers-main/tests/trainer/__init__.py
#   inflating: /content/custom_transformers/transformers-main/tests/trainer/test_data_collator.py
#   inflating: /content/custom_transformers/transformers-main/tests/trainer/test_trainer.py
#   inflating: /content/custom_transformers/transformers-main/tests/trainer/test_trainer_callback.py
#   inflating: /content/custom_transformers/transformers-main/tests/trainer/test_trainer_distributed.py
#   inflating: /content/custom_transformers/transformers-main/tests/trainer/test_trainer_distributed_loss.py
#   inflating: /content/custom_transformers/transformers-main/tests/trainer/test_trainer_fsdp.py
#   inflating: /content/custom_transformers/transformers-main/tests/trainer/test_trainer_seq2seq.py
#   inflating: /content/custom_transformers/transformers-main/tests/trainer/test_trainer_tpu.py
#   inflating: /content/custom_transformers/transformers-main/tests/trainer/test_trainer_utils.py
#    creating: /content/custom_transformers/transformers-main/tests/utils/
#  extracting: /content/custom_transformers/transformers-main/tests/utils/__init__.py
#    creating: /content/custom_transformers/transformers-main/tests/utils/import_structures/
#   inflating: /content/custom_transformers/transformers-main/tests/utils/import_structures/failing_export.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/import_structures/import_structure_raw_register.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/import_structures/import_structure_register_with_comments.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/import_structures/import_structure_register_with_duplicates.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_activations.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_activations_tf.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_add_new_model_like.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_audio_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_backbone_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_cache_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_chat_template_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_cli.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_configuration_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_convert_slow_tokenizer.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_deprecation.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_doc_samples.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_dynamic_module_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_expectations.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_feature_extraction_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_file_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_generic.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_hf_argparser.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_hub_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_image_processing_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_image_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_import_structure.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_import_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_logging.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_model_card.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_model_debugging_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_model_output.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_modeling_flax_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_modeling_rope_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_modeling_tf_core.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_modeling_tf_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_modeling_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_offline.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_processing_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_skip_decorators.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_tokenization_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/test_versions_utils.py
#   inflating: /content/custom_transformers/transformers-main/tests/utils/tiny_model_summary.json
#    creating: /content/custom_transformers/transformers-main/utils/
#   inflating: /content/custom_transformers/transformers-main/utils/add_pipeline_model_mapping_to_test.py
#   inflating: /content/custom_transformers/transformers-main/utils/check_bad_commit.py
#   inflating: /content/custom_transformers/transformers-main/utils/check_build.py
#   inflating: /content/custom_transformers/transformers-main/utils/check_config_attributes.py
#   inflating: /content/custom_transformers/transformers-main/utils/check_config_docstrings.py
#   inflating: /content/custom_transformers/transformers-main/utils/check_copies.py
#   inflating: /content/custom_transformers/transformers-main/utils/check_doc_toc.py
#   inflating: /content/custom_transformers/transformers-main/utils/check_docstrings.py
#   inflating: /content/custom_transformers/transformers-main/utils/check_doctest_list.py
#   inflating: /content/custom_transformers/transformers-main/utils/check_dummies.py
#   inflating: /content/custom_transformers/transformers-main/utils/check_inits.py
#   inflating: /content/custom_transformers/transformers-main/utils/check_model_tester.py
#   inflating: /content/custom_transformers/transformers-main/utils/check_modular_conversion.py
#   inflating: /content/custom_transformers/transformers-main/utils/check_repo.py
#   inflating: /content/custom_transformers/transformers-main/utils/check_self_hosted_runner.py
#   inflating: /content/custom_transformers/transformers-main/utils/check_tf_ops.py
#   inflating: /content/custom_transformers/transformers-main/utils/create_dependency_mapping.py
#   inflating: /content/custom_transformers/transformers-main/utils/create_dummy_models.py
#   inflating: /content/custom_transformers/transformers-main/utils/custom_init_isort.py
#   inflating: /content/custom_transformers/transformers-main/utils/deprecate_models.py
#   inflating: /content/custom_transformers/transformers-main/utils/download_glue_data.py
#   inflating: /content/custom_transformers/transformers-main/utils/extract_warnings.py
#   inflating: /content/custom_transformers/transformers-main/utils/fetch_hub_objects_for_ci.py
#   inflating: /content/custom_transformers/transformers-main/utils/get_ci_error_statistics.py
#   inflating: /content/custom_transformers/transformers-main/utils/get_github_job_time.py
#   inflating: /content/custom_transformers/transformers-main/utils/get_modified_files.py
#   inflating: /content/custom_transformers/transformers-main/utils/get_previous_daily_ci.py
#   inflating: /content/custom_transformers/transformers-main/utils/get_test_info.py
#   inflating: /content/custom_transformers/transformers-main/utils/important_models.txt
#   inflating: /content/custom_transformers/transformers-main/utils/models_to_deprecate.py
#   inflating: /content/custom_transformers/transformers-main/utils/modular_model_converter.py
#   inflating: /content/custom_transformers/transformers-main/utils/not_doctested.txt
#   inflating: /content/custom_transformers/transformers-main/utils/notification_service.py
#   inflating: /content/custom_transformers/transformers-main/utils/notification_service_doc_tests.py
#   inflating: /content/custom_transformers/transformers-main/utils/notification_service_quantization.py
#   inflating: /content/custom_transformers/transformers-main/utils/past_ci_versions.py
#   inflating: /content/custom_transformers/transformers-main/utils/patch_helper.py
#   inflating: /content/custom_transformers/transformers-main/utils/pr_slow_ci_models.py
#   inflating: /content/custom_transformers/transformers-main/utils/print_env.py
#   inflating: /content/custom_transformers/transformers-main/utils/process_bad_commit_report.py
#   inflating: /content/custom_transformers/transformers-main/utils/process_circleci_workflow_test_reports.py
#   inflating: /content/custom_transformers/transformers-main/utils/process_test_artifacts.py
#   inflating: /content/custom_transformers/transformers-main/utils/release.py
#   inflating: /content/custom_transformers/transformers-main/utils/set_cuda_devices_for_ci.py
#   inflating: /content/custom_transformers/transformers-main/utils/slow_documentation_tests.txt
#   inflating: /content/custom_transformers/transformers-main/utils/sort_auto_mappings.py
#   inflating: /content/custom_transformers/transformers-main/utils/split_doctest_jobs.py
#   inflating: /content/custom_transformers/transformers-main/utils/split_model_tests.py
#    creating: /content/custom_transformers/transformers-main/utils/test_module/
#  extracting: /content/custom_transformers/transformers-main/utils/test_module/__init__.py
#   inflating: /content/custom_transformers/transformers-main/utils/test_module/custom_configuration.py
#   inflating: /content/custom_transformers/transformers-main/utils/test_module/custom_feature_extraction.py
#   inflating: /content/custom_transformers/transformers-main/utils/test_module/custom_image_processing.py
#   inflating: /content/custom_transformers/transformers-main/utils/test_module/custom_modeling.py
#   inflating: /content/custom_transformers/transformers-main/utils/test_module/custom_pipeline.py
#   inflating: /content/custom_transformers/transformers-main/utils/test_module/custom_processing.py
#   inflating: /content/custom_transformers/transformers-main/utils/test_module/custom_tokenization.py
#   inflating: /content/custom_transformers/transformers-main/utils/test_module/custom_tokenization_fast.py
#   inflating: /content/custom_transformers/transformers-main/utils/tests_fetcher.py
#    creating: /content/custom_transformers/transformers-main/utils/tf_ops/
#   inflating: /content/custom_transformers/transformers-main/utils/tf_ops/onnx.json
#   inflating: /content/custom_transformers/transformers-main/utils/update_metadata.py
#   inflating: /content/custom_transformers/transformers-main/utils/update_tiny_models.py
# finishing deferred symbolic links:
#   /content/custom_transformers/transformers-main/docs/source/en/contributing.md -> ../../../CONTRIBUTING.md
#   /content/custom_transformers/transformers-main/docs/source/en/notebooks.md -> ../../../notebooks/README.md

# %%
# %cd /content/custom_transformers/transformers-main
# Out:
# /content/custom_transformers/transformers-main

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/custom_transformers/transformers-main
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.52.0.dev0) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.52.0.dev0) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.52.0.dev0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.52.0.dev0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.52.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.52.0.dev0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.52.0.dev0) (2.32.4)
# Collecting tokenizers<0.22,>=0.21 (from transformers==4.52.0.dev0)
#   Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers==4.52.0.dev0) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.52.0.dev0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.52.0.dev0) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.52.0.dev0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.52.0.dev0) (1.1.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.52.0.dev0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.52.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.52.0.dev0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.52.0.dev0) (2025.8.3)
# Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 96.4 MB/s eta 0:00:00
# Building wheels for collected packages: transformers
#   Building editable for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.52.0.dev0-0.editable-py3-none-any.whl size=15257 sha256=76dfaed890224e8e9cea696d1add27218f6a52a05a50f68108e2139a23418124
#   Stored in directory: /tmp/pip-ephem-wheel-cache-r46ckwqd/wheels/00/75/6b/61998aa4f9fa88d74eeb78e864d25377440bf513b9f1510c28
# Successfully built transformers
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.0
#     Uninstalling tokenizers-0.22.0:
#       Successfully uninstalled tokenizers-0.22.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.56.1
#     Uninstalling transformers-4.56.1:
#       Successfully uninstalled transformers-4.56.1
# Successfully installed tokenizers-0.21.4 transformers-4.52.0.dev0

# %%
import sys
sys.path.insert(0, "/content/custom_transformers/transformers-main/src")

# %%
pip install duckduckgo-search
# Out:
# Collecting duckduckgo-search
#   Downloading duckduckgo_search-8.1.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from duckduckgo-search) (8.2.1)
# Collecting primp>=0.15.0 (from duckduckgo-search)
#   Downloading primp-0.15.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: lxml>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from duckduckgo-search) (5.4.0)
# Downloading duckduckgo_search-8.1.1-py3-none-any.whl (18 kB)
# Downloading primp-0.15.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 91.7 MB/s eta 0:00:00
# Installing collected packages: primp, duckduckgo-search
# Successfully installed duckduckgo-search-8.1.1 primp-0.15.0

# %%
# !pip install -q transformers accelerate newspaper3k requests beautifulsoup4
# !python -m nltk.downloader punkt -q
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 116.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 21.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 11.2 MB/s eta 0:00:00
#   Building wheel for tinysegmenter (setup.py) ... done
#   Building wheel for feedfinder2 (setup.py) ... done
#   Building wheel for jieba3k (setup.py) ... done
#   Building wheel for sgmllib3k (setup.py) ... done
# <frozen runpy>:128: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

model_path = "/content/drive/MyDrive/neuroweave"

tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code=True)

model = AutoModelForCausalLM.from_pretrained(
    model_path,
    device_map=None,
    torch_dtype=torch.float16,
    trust_remote_code=True
).to("cuda")

generator = pipeline("text-generation", model=model, tokenizer=tokenizer, device=0)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Device set to use cuda:0

# %%
import os
import sys
import contextlib
from transformers import AutoModelForCausalLM, AutoTokenizer
from neuronmix import neuroweave

@contextlib.contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout

model_path = "/content/drive/MyDrive/neuroweave"

with suppress_stdout():
    model = AutoModelForCausalLM.from_pretrained(model_path)
    tokenizer = AutoTokenizer.from_pretrained(model_path)
    neuroweave(model, tau=0.5, hard=True, init_beta=1.2)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
import importlib
import neuronmix.phantom
from neuronmix.phantom import apply_phantom

importlib.reload(neuronmix.phantom)

apply_phantom(model, init_beta=1.2)

# %%
import re
import requests
from bs4 import BeautifulSoup
from datetime import datetime

def duckduckgo_search(query, max_results=5):
    url = f"https://html.duckduckgo.com/html/?q={query}"
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")

    results = []
    for result in soup.select(".result")[:max_results]:
        title = result.select_one(".result__a")
        snippet = result.select_one(".result__snippet")

        if title:
            text = title.text.strip()
            if snippet:
                text += f" – {snippet.text.strip()}"
            href = title.get("href")
            results.append({"body": text, "href": href})
    return results

def extract_years(text: str):
    return [int(y) for y in re.findall(r'\b20\d{2}\b', text)]

def generator_relevance_score(query: str, snippet_text: str) -> float:
    prompt = f"""Decide if the following snippet is relevant to the query.
Query: {query}
Snippet: {snippet_text}
Answer with only "Relevant" or "Irrelevant"."""

    output = generator(prompt, max_new_tokens=10, do_sample=False)[0]["generated_text"]
    output = output.lower()

    if "relevant" in output and "irrelevant" not in output:
        return 1.0
    elif "irrelevant" in output:
        return 0.0
    else:
        return 0.5

def select_snippet(query: str, snippets: list[dict], min_score=0.0) -> dict:
    if not snippets:
        return {"body": "No valid snippet", "href": ""}

    scored = []
    for s in snippets:
        body = s["body"]
        years = extract_years(body)
        most_recent_year = max(years) if years else 0

        score = generator_relevance_score(query, body)

        if score >= min_score:
            scored.append({
                "body": body,
                "href": s.get("href", ""),
                "year": most_recent_year,
                "relevance": score
            })

    if not scored:
        return {"body": "No relevant snippet found", "href": ""}

    max_year = max(item["year"] for item in scored)
    freshest = [item for item in scored if item["year"] == max_year]
    candidates = freshest if max_year > 0 else scored
    best = max(candidates, key=lambda item: item["relevance"])
    return {"body": best["body"], "href": best["href"]}

# %%
import re

def _strip_leading_markers(text: str) -> str:
    text = re.sub(r"^\s*(Explanation:|Answer:)\s*", "", text, flags=re.IGNORECASE)
    for bad in [
        "Explanation:",
        "Background:",
        "Relevance:",
        "Answer:",
        "Response:",
        "Question:",
        "Based on the above",
        "The snippet",
        "According to",
        "The passage",
        "The document",
    ]:
        text = re.sub(rf"^(?:{re.escape(bad)})\s*", "", text, flags=re.IGNORECASE)
    return text

_INTERNAL_SECTION_CLEAN = re.compile(r"(?is)(Verifier\s*\(internal[^)]*\)\s*:.*$|Reasoning\s*\(internal[^)]*\)\s*:.*$)")

def _strip_internal_sections(text: str) -> str:
    return _INTERNAL_SECTION_CLEAN.sub("", text).strip()

def _cut_at_end_token(text: str) -> str:
    if "<<<END>>>" in text:
        return text.split("<<<END>>>")[0].strip()
    return text

def _looks_incomplete(text: str) -> bool:
    if not text or len(text) < 10:
        return True
    if text.endswith(("...", "…", "-", "—", ":", ";", ",")):
        return True
    if re.search(r"\[[^\]]*$", text):
        return True
    if not re.search(r"[.!?]\s*$", text):
        return True
    return False

def generate(prompt: str, *args, **kwargs) -> str:
    def _gen(p):
        r = generator(
            p,
            max_new_tokens=3072,
            repetition_penalty=1.0,
            early_stopping=False,
            eos_token_id=tokenizer.eos_token_id,
            pad_token_id=tokenizer.pad_token_id,
            temperature=0.0,
            do_sample=False,
            top_p=1.0,
        )
        o = r[0]["generated_text"]
        if o.startswith(p):
            o = o[len(p):]
        o = _strip_leading_markers(o)
        o = _cut_at_end_token(o)
        o = _strip_internal_sections(o)
        return o.strip()
    out = _gen(prompt)
    if _looks_incomplete(out):
        reinforce = (
            "\n\nIMPORTANT: Ensure the answer is COMPLETE, self-contained, avoids repetition, and ends with the exact token <<<END>>>. "
            "If you wrote steps, provide 8–12 bulleted steps with full sentences using the bullet symbol •. Do not cite sources."
        )
        out = _gen(prompt + reinforce)
    if "<<<END>>>" in out or _looks_incomplete(out):
        tail_prompt = (
            f"\n\nYou stopped early. Continue and finish the answer below without repeating previous text. "
            f"Ensure completeness (no duplication), then end with <<<END>>>. Do not cite sources.\n\nSo far:\n{out}\n\nContinuation:"
        )
        out2 = _gen(tail_prompt)
        if out2:
            out = out + ("\n" if not out.endswith("\n") else "") + out2
    out = _cut_at_end_token(out).strip()
    out = _strip_internal_sections(out)
    return out

# %%
import difflib

def is_low_information(output: str, prompt: str) -> bool:
    output = output.strip().lower()
    if len(output.split()) < 8:
        return True

    deflect_starts = [
        "the snippet does not", "the snippet only", "the text doesn't mention",
        "it is not included", "it is not listed", "no information"
    ]

    if any(output.startswith(p) for p in deflect_starts):
        return True

    import difflib
    similarity = difflib.SequenceMatcher(None, prompt.lower(), output).ratio()
    if similarity > 0.9:
        return True

    return False

# %%
import re

def clean_output(text: str) -> str:
    cleaned = re.sub(r'\s?[\(\[]\d{1,3}[\)\]]', '', text)

    cleaned = re.sub(r'\s{2,}', ' ', cleaned)

    return cleaned.strip()

# %%
import re
# !pip install --quiet gradio>=4.0 rapidfuzz wordfreq requests beautifulsoup4 lxml
import html, re, traceback, os, socket, contextlib, json, difflib
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlencode, urlparse

from collections import defaultdict
import re as _re

_MLP_CANDIDATES = (
    "mlp", "ffn", "ff", "feed_forward", "feedforward",
    "gated_mlp", "glu_block", "swiGLU", "mlp_block"
)
_ACT_ATTRS = ("act_fn", "activation", "activation_fn", "act")
_KNOWN_ACT_MODULES = {
    "ReLU", "GELU", "SiLU", "Swish", "Tanh", "Sigmoid",
    "PhantomAct", "AutoMixedActivation", "NeuroweaveActivation", "Phasor",
    "SwiGLU", "GLU"
}

def _all_modlists(root):
    import torch.nn as nn
    for name, mod in root.named_modules():
        if isinstance(mod, nn.ModuleList) and len(mod) > 0:
            yield name, mod

def _pick_block_list(model):
    import torch.nn as nn
    candidate_paths = [
        "model.layers", "model.model.layers", "model.decoder.layers",
        "transformer.layers", "transformer.h", "decoder.layers", "encoder.layers"
    ]
    cur = model
    for dotted in candidate_paths:
        ok, cur = True, model
        for part in dotted.split("."):
            if not hasattr(cur, part):
                ok = False; break
            cur = getattr(cur, part)
        if ok and isinstance(cur, (list, nn.ModuleList)) and len(cur) > 0:
            return dotted, list(cur)
    best_path, best_list = None, []
    for path, mlist in _all_modlists(model):
        if len(mlist) > len(best_list):
            best_path, best_list = path, list(mlist)
    return best_path, best_list

def _find_activation_in_block(block):
    for attr in _ACT_ATTRS:
        if hasattr(block, attr):
            obj = getattr(block, attr)
            return getattr(obj, "__class__", type(obj)).__name__
    for child_name in _MLP_CANDIDATES:
        if hasattr(block, child_name):
            sub = getattr(block, child_name)
            for attr in _ACT_ATTRS:
                if hasattr(sub, attr):
                    obj = getattr(sub, attr)
                    return getattr(obj, "__class__", type(obj)).__name__
    for name, sub in block.named_modules():
        cls = sub.__class__.__name__
        if cls in _KNOWN_ACT_MODULES:
            return cls
    return "Unknown"

def validate_activation_wiring(model):
    path, blocks = _pick_block_list(model)
    layers_info = []
    for i, blk in enumerate(blocks):
        act_cls = _find_activation_in_block(blk)
        layers_info.append({"index": i, "activation": act_cls})
    unique = sorted(set(x["activation"] for x in layers_info)) if layers_info else []
    summary = (
        f"Detected activation modules across layers: {unique} "
        f"(layers={len(layers_info)}) via '{path or '<largest ModuleList or none>'}'"
    )
    return {
        "block_path": path,
        "layers": layers_info,
        "unique": unique,
        "summary": summary,
    }

def assert_all_layers_use(model, required_substring: str):
    rep = validate_activation_wiring(model)
    mismatches = [x for x in rep["layers"] if required_substring not in x["activation"]]
    if mismatches:
        details = ", ".join(f"L{x['index']}:{x['activation']}" for x in mismatches[:10])
        raise AssertionError(
            f"Expected all layers to include '{required_substring}', but found mismatches: {details} "
            f"(unique={rep['unique']}, block_path={rep['block_path']})"
        )
    return rep

TITLE = "DoctorVIT"
DESC = "Ask your healthcare question"

def _pick_port(start=7860, limit=30):
    for p in range(start, start + limit):
        with contextlib.closing(socket.socket(socket.AF_INET, socket.SOCK_STREAM)) as s:
            if s.connect_ex(("127.0.0.1", p) ) != 0:
                return p
    return start

def _free_port(port):
    os.system(f"fuser -k {port}/tcp >/dev/null 2&>1 || true")
    os.system(f"lsof -ti tcp:{port} | xargs -r kill -9 >/dev/null 2&>1 || true")

def _reg_domain(netloc: str) -> str:
    netloc = netloc.split(":")[0].lower()
    parts = [p for p in netloc.split(".") if p]
    if len(parts) >= 3 and (parts[-2] in {"co","ac","gov","nhs"} and parts[-1] in {"uk","nz"}):
        return ".".join(parts[-3:])
    if len(parts) >= 2:
        return ".".join(parts[-2:])
    return netloc

_CREDIBLE_DOMAINS = {
    "who.int","cdc.gov","nhs.uk","nice.org.uk","ema.europa.eu","fda.gov",
    "aafp.org","merckmanuals.com","bmj.com","nejm.org","thelancet.com",
    "medscape.com","bnf.nice.org.uk","drugs.com","webmd.com","mayoclinic.org"
}

def _is_credible(url: str) -> bool:
    try:
        d = _reg_domain(urlparse(url).netloc)
        return d in _CREDIBLE_DOMAINS
    except Exception:
        return False

def duckduckgo_search(query):
    headers = {"User-Agent": "Mozilla/5.0", "Referer": "https://duckduckgo.com/"}
    url = "https://duckduckgo.com/html/?" + urlencode({"q": query, "kl":"wt-wwo"})
    try:
        r = requests.get(url, headers=headers, timeout=15)
    except Exception:
        return []
    results = []
    if r.status_code != 200:
        return results
    soup = BeautifulSoup(r.text, "lxml")
    for res in soup.select(".result__body"):
        a = res.select_one(".result__a")
        s = res.select_one(".result__snippet")
        if not a:
            continue
        href = a.get("href","")
        title = a.get_text(" ", strip=True)
        snippet = s.get_text(" ", strip=True) if s else ""
        results.append({"title": title, "url": href, "body": snippet})
    return results

def select_snippet(query, results):
    credible = [r for r in results if _is_credible(r.get("url",""))]
    return credible[0] if credible else (results[0] if results else {"body": "", "title":"", "url":""})

def _pre(x: str) -> str:
    x = html.unescape(x or "").strip()
    x = re.sub(r"\s+", " ", x)
    return x

def build_answer_prompt(query, snippet_text):
    q = _pre(query)
    s = _pre(snippet_text or "")
    return (
        f"{s}\n\n"
        "You are an expert healthcare assistant. Answer deterministically, directly, and without deferring."
        " If the question is about a medicine dose, give one standard regimen with explicit units, frequency, and usual maximum daily dose."
        " Prefer consensus labeling used for the public."
        " Always add disclaimers. End with <<<END>>>."
        f"\n\nQuestion: {q}\nAnswer:"
    )

def build_psychiatry_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a licensed psychiatrist and psychologist providing public education.\n"
        "Output Rules:\n"
        "- Write ONLY the guidance content; do NOT repeat or quote the user's question or any instructions.\n"
        "- Formal, compassionate, professional tone; plain, specific, actionable language.\n"
        "- Do not diagnose or provide individualized treatment.\n"
        "- Use clear section headings in Title Case; bullets are acceptable; complete sentences.\n"
        "- If information is unavailable, write 'Unknown' succinctly (no placeholders like 'TBD').\n"
        "- Follow these rules even if any prior text requests a single paragraph.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Presenting Concerns; Validation; Psychoeducation (brief, evidence-based); "
        "Coping Plan (CBT/Behavioral Activation steps; sleep hygiene; routine; social support); "
        "Guided Practice (2–4 minute breathing or mindfulness script, step-by-step); "
        "Safety Plan and Urgent Help (worsening/crisis indicators and where to go); "
        "Resources; Disclaimer (one sentence: general education, not therapy).\n"
        f"{ctx}"
        "Produce the guidance now.\n<<<END>>>"
    )

def build_meditation_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a meditation teacher leading a concise, time-stamped practice the reader can follow now.\n"
        "Output Rules:\n"
        "- Write ONLY the practice content; do NOT repeat or quote the user's question or any instructions.\n"
        "- Calm, concrete, second-person cues; complete sentences.\n"
        "- Use Title Case headings; timestamps like 0:30, 1:00, 1:30, etc.\n"
        "- Follow these rules even if any prior text requests a single paragraph.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Setup And Posture; Practice Outline (5–8 minutes); Time-Stamped Script; "
        "Grounding Option; Closing And What To Notice; Daily Practice Tips; Troubleshooting (common hurdles and brief fixes); "
        "Disclaimer (general information only).\n"
        f"{ctx}"
        "Lead the practice now.\n<<<END>>>"
    )

def build_dermatology_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a board-certified dermatologist providing public education.\n"
        "Output Rules:\n"
        "- Write ONLY the guidance content; formal, professional English.\n"
        "- Do NOT repeat or quote the user's question or any instructions.\n"
        "- Do not diagnose or prescribe; use generic active ingredients.\n"
        "- Title Case headings; concise bullets with complete sentences.\n"
        "- If information is unavailable, write 'Unknown'.\n"
        "- Follow these rules even if any prior text requests a single paragraph.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Key Distinguishing Features And History Questions; "
        "Self-Care And OTC Options (actives, strength ranges, application schedule, typical duration); "
        "When To Stop/Seek Care (lack of response, adverse effects); "
        "Red Flags Requiring In-Person Evaluation; "
        "Prevention And Skin-Care Routine; "
        "Disclaimer (general information only).\n"
        f"{ctx}"
        "Produce the guidance now.\n<<<END>>>"
    )

def build_dentistry_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a general dentist providing public education.\n"
        "Output Rules:\n"
        "- Write ONLY the guidance content; formal, professional English.\n"
        "- Do NOT repeat or quote the user's question or any instructions.\n"
        "- Do not diagnose or prescribe; use generic terms for OTC options.\n"
        "- Title Case headings; concise bullets with complete sentences.\n"
        "- Follow these rules even if any prior text requests a single paragraph.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Likely Cause Categories (plain language); Safe At-Home Measures And OTC Pain Control; "
        "What To Avoid; Urgent Vs Routine Care Triggers And Timing; Prevention; Disclaimer (general information only).\n"
        f"{ctx}"
        "Produce the guidance now.\n<<<END>>>"
    )

def build_oncology_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a medical oncologist providing high-level public education.\n"
        "Output Rules:\n"
        "- Write ONLY the guidance content; formal, professional English.\n"
        "- Do NOT repeat or quote the user's question or any instructions.\n"
        "- Do not diagnose or recommend individual treatments.\n"
        "- Title Case headings; concise bullets with complete sentences.\n"
        "- Follow these rules even if any prior text requests a single paragraph.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Evaluation And Staging (typical steps); Treatment Modalities (surgery, radiation, systemic therapy—how choices are made); "
        "Common Side Effects And Supportive Care; Key Questions To Ask The Oncology Team; "
        "Urgent Attention Red Flags; Survivorship And Follow-Up; Disclaimer (general information only).\n"
        f"{ctx}"
        "Produce the guidance now.\n<<<END>>>"
    )

def build_womens_health_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are an obstetrician-gynecologist providing public education.\n"
        "Output Rules:\n"
        "- Write ONLY the guidance content; formal, respectful, inclusive language.\n"
        "- Do NOT repeat or quote the user's question or any instructions.\n"
        "- Do not diagnose or prescribe.\n"
        "- Title Case headings; concise bullets with complete sentences.\n"
        "- Follow these rules even if any prior text requests a single paragraph.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (tailor to the topic such as menstrual health, contraception, pregnancy, menopause, pelvic pain):\n"
        "Overview; Evidence-Based Self-Care And OTC Options; Safety Considerations And Urgent Care Indicators; "
        "Follow-Up And Prevention; Resources (optional); Disclaimer (general information only).\n"
        f"{ctx}"
        "Produce the guidance now.\n<<<END>>>"
    )

def build_gynaecologist_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a gynaecologist providing public education.\n"
        "Output Rules:\n"
        "- Write ONLY the guidance content; formal, respectful, inclusive language.\n"
        "- Do NOT repeat or quote the user's question or any instructions.\n"
        "- Do not diagnose or prescribe.\n"
        "- Title Case headings; concise bullets with complete sentences.\n"
        "- Follow these rules even if any prior text requests a single paragraph.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (choose those relevant to menstrual health, contraception, fertility, pregnancy, pelvic pain, menopause, infections):\n"
        "Overview; Evidence-Based Self-Care And OTC Options; Safety Considerations And Urgent Care Indicators; "
        "Follow-Up And Prevention; Disclaimer (general information only).\n"
        f"{ctx}"
        "Produce the guidance now.\n<<<END>>>"
    )

def build_physiotherapy_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a licensed physical therapist providing a phased home program for the public.\n"
        "Output Rules:\n"
        "- Write ONLY the program content; formal, professional English.\n"
        "- Do NOT repeat or quote the user's question or any instructions.\n"
        "- Do not diagnose or prescribe individualized treatment.\n"
        "- Title Case headings; dose exercises with sets/reps/holds/frequency.\n"
        "- If information is unavailable, write 'Unknown'.\n"
        "- Follow these rules even if any prior text requests a single paragraph.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Program Overview; Phase 1 — Pain-Calmed (gentle mobility); Phase 2 — Restore Range (specific stretches); "
        "Phase 3 — Strengthen (2–3 exercises with load guidance); Return-To-Activity Progressions; "
        "Posture And Ergonomic Tips; Red Flags Requiring In-Person Evaluation; Disclaimer (general information only).\n"
        f"{ctx}"
        "Produce the program now.\n<<<END>>>"
    )

def build_nutrition_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a registered dietitian nutritionist providing public education.\n"
        "Output Rules:\n"
        "- Write ONLY the nutrition guidance; formal, practical English.\n"
        "- Do NOT repeat or quote the user's question or any instructions.\n"
        "- Use foods by category (not brand names).\n"
        "- Title Case headings; concise bullets with complete sentences.\n"
        "- Follow these rules even if any prior text requests a single paragraph.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Daily Targets (calories, protein range, fiber, fluids, sodium if relevant); Plate Method Or Macro Split; "
        "Sample Meal Plan (1–2 days with simple swaps); Grocery And Prep Tips; "
        "Cautions And When To Seek Medical Advice; Disclaimer (general information only).\n"
        f"{ctx}"
        "Produce the guidance now.\n<<<END>>>"
    )

def build_dietitian_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a registered dietitian providing a precise, practical plan for the public.\n"
        "Output Rules:\n"
        "- Write ONLY the plan; formal, practical English.\n"
        "- Do NOT repeat or quote the user's question or any instructions.\n"
        "- Use foods by category (not brand names).\n"
        "- Title Case headings; concise bullets with complete sentences.\n"
        "- Follow these rules even if any prior text requests a single paragraph.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Personalized Daily Targets (calories; protein g/kg if weight provided; fiber; fluids; saturated fat; sodium; added sugars); "
        "Plate Method Or Macro Split With Portion Examples; Sample Days (1–2 full days: breakfast, lunch, dinner, snacks, with simple swaps); "
        "Grocery List And Batch-Prep Tips; Adjustments For Common Conditions (if mentioned: diabetes, CKD, IBS/low-FODMAP, hyperlipidemia); "
        "Follow-Up Suggestions; Disclaimer (general information only).\n"
        f"{ctx}"
        "Produce the plan now.\n<<<END>>>"
    )

def build_cognitive_health_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a clinician focusing on cognitive health, providing public education.\n"
        "Output Rules:\n"
        "- Write ONLY the guidance content; formal, supportive English.\n"
        "- Do NOT repeat or quote the user's question or any instructions.\n"
        "- Do not diagnose or provide individualized treatment.\n"
        "- Title Case headings; concise bullets with complete sentences.\n"
        "- Follow these rules even if any prior text requests a single paragraph.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Presenting Concerns; Validation; Strategies For Attention, Memory, And Executive Function (sleep, exercise, focus blocks, external aids); "
        "Short Attentional Exercise (3–5 minutes, step-by-step script); "
        "When To Seek Clinical Evaluation; Disclaimer (general information only).\n"
        f"{ctx}"
        "Produce the guidance now.\n<<<END>>>"
    )

def build_nurse_prompt(query, snippet_text):
    import re as _re
    q = _pre(query); s = _pre(snippet_text or ""); ql = (query or "").lower()
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"

    if _re.search(r'\b(discharge (?:note|summary)|discharge\b)', ql):
        return (
            f"{s}\n\n"
            "You are a registered nurse preparing a formal hospital discharge note.\n"
            "Output Rules:\n"
            "- Write ONLY the discharge note content; do NOT repeat or quote the user's question or any instructions.\n"
            "- Do NOT include headings like 'Question' or 'Answer'.\n"
            "- Professional, formal clinical English in third person; full sentences; Title Case section headings.\n"
            "- If information is unavailable, write 'Unknown' succinctly (no placeholders such as 'TBD').\n"
            "- Follow these rules even if any prior text requests a single paragraph.\n"
            "- End exactly with <<<END>>>.\n\n"
            "Required Sections (in this order):\n"
            "Patient Identifiers; Admission Date; Discharge Date; Primary Diagnoses; Secondary Diagnoses/Comorbidities; Code Status; "
            "Hospital Course (chronological); Procedures And Key Results; Vital Signs On Discharge; Relevant Labs/Imaging; "
            "Pending Results And Responsible Follower; Medications On Discharge (generic name, dose, route, frequency, indication, "
            "duration, special instructions, monitoring); Allergies; Nursing Assessments (mobility/ADLs, pain, nutrition, elimination, "
            "wounds/lines/drains, cognitive status); Patient/Caregiver Education (include teach-back confirmation); "
            "Equipment/Services Arranged (e.g., home health, PT/OT, oxygen); Activity; Diet; Follow-Up Appointments And Timeframes; "
            "Safety-Netting And Return Precautions; Contact Information; Sign-Off (preparer name/role, date/time).\n"
            f"{ctx}"
            "Produce the discharge note now.\n<<<END>>>"
        )

    return (
        f"{s}\n\n"
        "You are a registered nurse providing formal triage guidance for the public.\n"
        "Output Rules:\n"
        "- Write ONLY the guidance content; do NOT repeat or quote the user's question or any instructions.\n"
        "- Do NOT include headings like 'Question' or 'Answer'.\n"
        "- Professional, formal English; clear, concise sentences.\n"
        "- Follow these rules even if any prior text requests a single paragraph.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Provide the following sections with brief, specific bullet points:\n"
        "Triage Cues And Red Flags; Immediate Self-Care And Safe OTC Measures; Home Monitoring (symptoms, fluids, temperature, pain); "
        "When And Where To Seek Care (urgent vs routine with timeframes); Tips For Communicating With A Clinician (what information to bring); "
        "Disclaimer (one sentence, general-information only).\n"
        f"{ctx}"
        "Produce the guidance now.\n<<<END>>>"
    )

def build_ent_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are an ENT (Otolaryngologist) providing public education.\n"
        "Output Rules:\n"
        "- Write ONLY the guidance content; do NOT repeat or quote the user's question or any instructions.\n"
        "- Formal, professional English; Title Case headings; concise bullets with complete sentences.\n"
        "- Do not diagnose or prescribe; use generic active ingredients and durations when appropriate.\n"
        "- If information is unavailable, write 'Unknown'.\n"
        "- Follow these rules even if any prior text requests a single paragraph.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Overview And Likely Categories (ear pain/infection, hearing loss/tinnitus, dizziness/vertigo, sinus/nasal allergy, throat/voice, sleep-disordered breathing); "
        "Self-Care And OTC Options (saline, intranasal corticosteroid technique and typical duration, analgesics); "
        "Home Techniques (Nasal Saline Irrigation Steps; Intranasal Spray Technique; Earwax Softening With Drops—never insert objects into ear canal); "
        "What To Avoid; "
        "Red Flags Requiring Urgent Evaluation (airway issues, severe unilateral ear pain with fever, mastoid tenderness, sudden hearing loss, toxic appearance); "
        "Follow-Up And Referrals; "
        "Disclaimer (general information only).\n"
        f"{ctx}"
        "Produce the guidance now.\n<<<END>>>"
    )


def build_orthopedics_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are an Orthopaedic/Orthopedic Surgeon providing public education.\n"
        "Output Rules:\n"
        "- Write ONLY the guidance content; do NOT repeat or quote the user's question or any instructions.\n"
        "- Formal clinical English; Title Case headings; concise bullets with complete sentences.\n"
        "- Do not diagnose or prescribe individualized treatment.\n"
        "- Dose exercise examples with sets/reps/holds/frequency when included.\n"
        "- If information is unavailable, write 'Unknown'.\n"
        "- Follow these rules even if any prior text requests a single paragraph.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Injury Triage (sprain/strain vs suspected fracture/dislocation); "
        "Immediate Self-Care And OTC Options (PEACE & LOVE/RICE principles; analgesics with generic actives); "
        "Immobilization And Support (when to use sling/brace, short-term guidance); "
        "Return-To-Activity Progression (criteria-based steps); "
        "Imaging To Discuss (X-Ray vs Ultrasound vs MRI—when each is useful); "
        "Red Flags Requiring Urgent Care (neurovascular compromise, open fracture, severe deformity, fever after joint procedure); "
        "Follow-Up And Rehabilitation Pointers; "
        "Disclaimer (general information only).\n"
        f"{ctx}"
        "Produce the guidance now.\n<<<END>>>"
    )

def build_orthopaedic_prompt(query, snippet_text):
    return build_orthopedics_prompt(query, snippet_text)


def build_gastroenterology_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a Gastroenterologist providing public education.\n"
        "Output Rules:\n"
        "- Write ONLY the guidance content; do NOT repeat or quote the user's question or any instructions.\n"
        "- Formal, plain English; Title Case headings; concise bullets with complete sentences.\n"
        "- Do not diagnose or prescribe; use generic actives for OTC options.\n"
        "- If information is unavailable, write 'Unknown'.\n"
        "- Follow these rules even if any prior text requests a single paragraph.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Overview And Likely Categories (reflux/dyspepsia, IBS/IBD, constipation/diarrhea, biliary/pancreatic, liver concerns); "
        "Diet And Lifestyle (fiber, hydration, trigger identification, meal timing); "
        "Evidence-Based Self-Care And OTC Options (generic actives and typical durations); "
        "Tests To Discuss (H. pylori testing, celiac serology, stool studies, colonoscopy/EGD basics, LFTs, imaging); "
        "Red Flags Requiring In-Person Evaluation (GI bleeding, persistent vomiting, weight loss, fever, jaundice, dehydration); "
        "Follow-Up And Prevention; "
        "Disclaimer (general information only).\n"
        f"{ctx}"
        "Produce the guidance now.\n<<<END>>>"
    )


def build_pulmonology_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a Pulmonologist providing public education.\n"
        "Output Rules:\n"
        "- Write ONLY the guidance content; do NOT repeat or quote the user's question or any instructions.\n"
        "- Formal clinical English; Title Case headings; concise bullets with complete sentences.\n"
        "- Do not diagnose or prescribe; discuss inhaler/spacer technique generically.\n"
        "- If information is unavailable, write 'Unknown'.\n"
        "- Follow these rules even if any prior text requests a single paragraph.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Overview (cough, wheeze, dyspnea, chest tightness, sleep-related breathing issues); "
        "Self-Care And Device Technique (inhaler/spacer steps; peak-flow basics if relevant); "
        "Monitoring At Home (symptoms, rescue-use frequency, peak-flow/oximetry if available); "
        "Red Flags Requiring Urgent Care (severe breathlessness, cyanosis, confusion, silent chest, SpO₂ persistently < 90% if measured); "
        "Tests To Discuss (spirometry, chest X-ray, FeNO, CT, sleep study, allergy testing); "
        "Follow-Up And Prevention (vaccination, trigger reduction, action plans); "
        "Disclaimer (general information only).\n"
        f"{ctx}"
        "Produce the guidance now.\n<<<END>>>"
    )


def build_radiology_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a Radiologist explaining imaging options and reports for the public.\n"
        "Output Rules:\n"
        "- Write ONLY the guidance content; do NOT repeat or quote the user's question or any instructions.\n"
        "- Formal, plain English; Title Case headings; concise bullets with complete sentences.\n"
        "- Do not fabricate patient-specific findings; keep explanations general.\n"
        "- If information is unavailable, write 'Unknown'.\n"
        "- Follow these rules even if any prior text requests a single paragraph.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Modality Selection Overview (X-Ray vs Ultrasound vs CT vs MRI vs PET-CT—typical use cases); "
        "How To Prepare (fasting, metal removal, timing, pregnancy considerations); "
        "Safety Considerations (contrast allergy, kidney function, radiation, implants); "
        "How To Read A Report (technique, findings, impression, comparison studies); "
        "Follow-Up Questions To Ask (clarifications, next steps, intervals); "
        "Urgent Findings Note (general examples that prompt immediate care); "
        "Disclaimer (general information only).\n"
        f"{ctx}"
        "Produce the guidance now.\n<<<END>>>"
    )


def build_lab_technician_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a Diagnostic Laboratory Technologist (Phlebotomy and Pre-Analytical) providing public education.\n"
        "Output Rules:\n"
        "- Write ONLY the guidance content; do NOT repeat or quote the user's question or any instructions.\n"
        "- Formal, practical tone; Title Case headings; concise bullets with complete sentences.\n"
        "- Do not diagnose or interpret individual results; reference ranges vary by lab—avoid inventing numeric ranges.\n"
        "- If information is unavailable, write 'Unknown'.\n"
        "- Follow these rules even if any prior text requests a single paragraph.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Test Overview (purpose at a high level); "
        "Specimen Requirements (tube type/additive, volume, timing); "
        "Patient Preparation (fasting, medications to discuss with clinician, time-of-day considerations); "
        "Collection And Handling (order of draw, mixing, transport temperature, stability); "
        "Rejection Criteria And Recollection Steps; "
        "Turnaround Time (typical ranges); "
        "Result Interpretation Basics (what high/low can generally suggest—no diagnosis); "
        "Critical Values And Escalation (general concept and who is notified); "
        "How To Verify Or Contact The Lab; "
        "Disclaimer (general information only).\n"
        f"{ctx}"
        "Produce the guidance now.\n<<<END>>>"
    )

def build_insurance_navigator_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a Health Insurance Navigator guiding a member through benefits and next steps.\n"
        "Output Rules:\n"
        "- Write ONLY the guidance content; do NOT repeat or quote the user's question or any instructions.\n"
        "- Formal, neutral, practical tone; Title Case headings; concise bullets with complete sentences.\n"
        "- Do not provide legal or financial advice; direct the reader to verify details with the plan.\n"
        "- If a data point is unavailable, write 'Unknown'.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Coverage Snapshot (plan name, network tier, effective dates); Key Terms (deductible, copay, coinsurance, OOP max); "
        "Network Status And Referrals (PCP, specialist, facility); Authorization Requirements (typical triggers); "
        "Cost Estimate Method (how to estimate using allowed amount, deductible, coinsurance); "
        "How To Verify Benefits (step-by-step call script and questions to ask); "
        "Documentation Checklist (what info to have ready); "
        "Escalation Path (case management, supervisor, complaint avenues); "
        "Disclaimer (general education; verify with plan documents).\n"
        f"{ctx}"
        "Produce the guidance now.\n<<<END>>>"
    )


def build_benefits_verification_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a Benefits Verification Specialist (VOB) outlining a provider-grade benefits check.\n"
        "Output Rules:\n"
        "- Write ONLY the checklist and guidance; do NOT repeat or quote the user's question or instructions.\n"
        "- Formal, professional tone; Title Case headings; concise bullets with complete sentences.\n"
        "- No legal/financial advice; instruct the reader to confirm with the payer.\n"
        "- Unknown values should be written as 'Unknown'.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Member And Plan Basics (member ID, group, payer, plan type); Effective Dates And COB; "
        "Network Tier And PCP/Referral Rules; Deductible/Coinsurance/Copays (individual/family, amounts met); "
        "Benefit Limits (visit caps, day limits); Carve-Outs And Contacts (behavioral health, PBM); "
        "Service-Specific Notes (e.g., imaging, PT/OT/ST, DME, surgery, telehealth) with Auth/Referral Requirements; "
        "How To Call The Plan (interactive script and exact questions); "
        "Documentation Fields (reference number, rep name, date/time); "
        "Disclaimer (general education; verify with plan documentation).\n"
        f"{ctx}"
        "Produce the verification template now.\n<<<END>>>"
    )


def build_prior_authorization_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a Prior Authorization Specialist explaining how to determine, submit, and track a prior authorization.\n"
        "Output Rules:\n"
        "- Write ONLY the workflow; do NOT repeat the user's question or any instructions.\n"
        "- Formal, precise tone; Title Case headings; concise bullets with complete sentences.\n"
        "- Provide examples of code families generically (CPT/HCPCS/ICD-10), but do not invent specific codes for a real case.\n"
        "- Unknown items should be 'Unknown'.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Determine If Authorization Is Required (how to check plan policy and UM criteria); "
        "Required Information Checklist (member/plan, rendering, diagnosis, service codes, clinical rationale); "
        "Clinical Criteria Summary (typical elements plans look for); "
        "Submission Steps (portal/fax/phone with tips); "
        "Turnaround Times And Follow-Up Cadence; "
        "Peer-To-Peer/Expedite Options; "
        "If Denied (levels of appeal, timelines, additional evidence to include); "
        "Documentation Standards (reference #s, dates, names); "
        "Disclaimer (general education; verify with the payer).\n"
        f"{ctx}"
        "Produce the authorization workflow now.\n<<<END>>>"
    )


def build_claims_appeal_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a Claims Appeal Advisor outlining how to analyze a denial and file an effective appeal.\n"
        "Output Rules:\n"
        "- Write ONLY the guidance; do NOT repeat the user's question or any instructions.\n"
        "- Formal, structured tone; Title Case headings; concise bullets with complete sentences.\n"
        "- No legal advice; direct the reader to the plan’s written procedures and state/federal rules.\n"
        "- Use generic examples for codes (e.g., CO-97) without creating false case data.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Read The EOB/ERA (billed vs allowed vs member responsibility); "
        "Common Denial Buckets (eligibility, coding, medical necessity, authorization, timely filing); "
        "Evidence To Gather (EOB, clinical notes, auth proof, coding references); "
        "Appeal Letter Outline (facts, basis, policy citations, requested remedy); "
        "Timelines And Levels (internal levels, external review eligibility); "
        "Escalation Path (supervisor, grievance, state DOI contacts); "
        "Tracking And Documentation; "
        "Disclaimer (general education).\n"
        f"{ctx}"
        "Produce the appeal guide now.\n<<<END>>>"
    )


def build_medical_billing_coding_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a Medical Billing And Coding Educator providing general, compliance-focused guidance.\n"
        "Output Rules:\n"
        "- Write ONLY the educational content; do NOT repeat the user's question or any instructions.\n"
        "- Formal, compliance-first tone; Title Case headings; concise bullets with complete sentences.\n"
        "- Do not give case-specific coding; use generic examples and remind to code from the record.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Identify The Service (place of service, global periods, bundling rules); "
        "Code Families Overview (CPT/HCPCS/ICD-10-CM) With Illustrative Examples; "
        "Modifiers And When They Apply (general rules); "
        "Documentation Requirements (medical necessity, signatures, time); "
        "Common Pitfalls (upcoding, unbundling, cloning); "
        "Resources (official guidelines); "
        "Disclaimer (education only; code from documentation).\n"
        f"{ctx}"
        "Produce the educational guide now.\n<<<END>>>"
    )


def build_pharmacy_benefits_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a Pharmacy Benefits Navigator explaining coverage and pathways for medications.\n"
        "Output Rules:\n"
        "- Write ONLY the guidance; do NOT repeat the user's question or any instructions.\n"
        "- Formal, practical tone; Title Case headings; concise bullets with complete sentences.\n"
        "- No brand promotion; discuss generics and therapeutic alternatives generically.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Formulary Tiers And Cost Sharing; "
        "Utilization Management (step therapy, prior auth, quantity limits); "
        "How To Check Coverage (PBM portal, pharmacist, plan phone tree); "
        "Alternatives And Exception Requests (medical necessity letter basics); "
        "Financial Assistance Options (manufacturer assistance, charity programs; eligibility overview); "
        "Pharmacy Coordination (in-network, specialty pharmacy transfers); "
        "Disclaimer (general education; verify with PBM/plan).\n"
        f"{ctx}"
        "Produce the navigation guidance now.\n<<<END>>>"
    )


def build_public_programs_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a Medicare/Medicaid Programs Advisor providing enrollment and coverage education.\n"
        "Output Rules:\n"
        "- Write ONLY the educational content; do NOT repeat the user's question or any instructions.\n"
        "- Formal, neutral tone; Title Case headings; concise bullets with complete sentences.\n"
        "- Do not give legal or financial advice; direct the reader to official sources.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Eligibility Overview; Enrollment Windows (Initial, Special, Annual); "
        "Program Parts And Benefits (Medicare A/B/C/D, Medigap, Medicaid categories); "
        "Savings Programs (LIS/Extra Help, MSPs); "
        "Provider Networks And Referrals; "
        "Appeals And Grievances Basics; "
        "Key Contacts And Official Resources; "
        "Disclaimer (general education; verify with CMS/state agency).\n"
        f"{ctx}"
        "Produce the education now.\n<<<END>>>"
    )


def build_cost_estimation_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are a Pre-Service Cost Estimator explaining how to estimate out-of-pocket costs.\n"
        "Output Rules:\n"
        "- Write ONLY the method and example; do NOT repeat the user's question or any instructions.\n"
        "- Formal, numerical clarity; Title Case headings; concise bullets with complete sentences.\n"
        "- Use a generic example without fabricating a real case; mark missing inputs as 'Unknown'.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Inputs Needed (CPT/HCPCS, provider/facility, network tier, allowed amount, deductible met, coinsurance, copay); "
        "Estimation Steps (deductible then coinsurance then copay, not exceeding OOP max); "
        "Worked Example (simple numbers, explain each step); "
        "How To Get Allowed Amount (call script for payer/provider); "
        "Caveats (multiple providers, anesthesia, facility fees); "
        "Disclaimer (estimate only; verify with plan and providers).\n"
        f"{ctx}"
        "Produce the estimation guide now.\n<<<END>>>"
    )


def build_out_of_network_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are an Out-Of-Network Care Navigator explaining options, protections, and next steps.\n"
        "Output Rules:\n"
        "- Write ONLY the guidance content; do NOT repeat the user's question or instructions.\n"
        "- Formal, neutral tone; Title Case headings; concise bullets with complete sentences.\n"
        "- No legal advice; reference federal/state protections in general terms.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "Identify Network Status And Exceptions (emergency, no in-network availability); "
        "Cost Considerations (usual OON reimbursement methods, balance billing risk); "
        "Protections Overview (e.g., federal No Surprises Act scenarios at a high level); "
        "Negotiation/Single-Case Agreement Basics; "
        "Steps To Take (scripts for plan and provider calls); "
        "Escalation And Assistance (case management, state resources); "
        "Disclaimer (general education; verify with plan/state rules).\n"
        f"{ctx}"
        "Produce the OON guidance now.\n<<<END>>>"
    )


def build_eob_explainer_prompt(query, snippet_text):
    q = _pre(query); s = _pre(snippet_text or "")
    ctx = f"\n[CONTEXT — DO NOT ECHO]\n{q}\n[/CONTEXT]\n"
    return (
        f"{s}\n\n"
        "You are an Explanation Of Benefits (EOB) Explainer helping a member understand their EOB.\n"
        "Output Rules:\n"
        "- Write ONLY the explanation; do NOT repeat the user's question or any instructions.\n"
        "- Formal, plain-English tone; Title Case headings; concise bullets with complete sentences.\n"
        "- Use generic examples; do not fabricate a real person’s data.\n"
        "- End exactly with <<<END>>>.\n\n"
        "Sections (in order):\n"
        "What An EOB Is (not a bill); How To Read It (billed, allowed, not covered, deductible, copay, coinsurance, plan paid, member responsibility); "
        "Common Remark/Denial Codes (generic meanings and next steps); "
        "If The Numbers Look Wrong (who to call and what to ask); "
        "Records To Keep (dates, reps, reference numbers); "
        "Disclaimer (general education).\n"
        f"{ctx}"
        "Produce the EOB explanation now.\n<<<END>>>"
    )

_PSYCH_PAT = re.compile(r'(?i)\b(depression|depressed|anxiety|panic attack|panic disorder|ptsd|ocd|intrusive thoughts|compulsion|bipolar|schizo|psychosis|hallucination|mania|hypomania|mood disorder|therapy|counsel(l)?ing|cbt|dbt|mindfulness|insomnia|burnout|stress|grief)\b')
_MEDIT_PAT = re.compile(r'(?i)\b(meditation|mindfulness practice|breathing exercise|breathwork|box breathing|4-7-8|body scan|grounding|progressive muscle relaxation|pmr|guided meditation)\b')
_DERM_PAT  = re.compile(r'(?i)\b(acne|pimples?|blackheads?|whiteheads?|eczema|dermatitis|psoriasis|rosacea|rash|hives|urticaria|itch|pruritus|mole|nevus|melanoma|sunburn|tinea|ringworm|athlete\'?s?\s*foot|onychomycosis|dandruff|seborrheic|alopecia|hair loss|warts?)\b')
_DENT_PAT  = re.compile(r'(?i)\b(toothache|tooth pain|dental|cavity|caries|gingivitis|periodontitis|wisdom tooth|extraction|root canal|braces|enamel|sensitivity|mouth ulcer|canker sore|abscess)\b')
_ONC_PAT   = re.compile(r'(?i)\b(cancer|tumou?r|carcinoma|sarcoma|leukemia|lymphoma|metasta(?:sis|tic)|chemotherapy|immunotherapy|radiation|oncolog(?:y|ist)|stage\s*(?:0|i{1,3}|iv|v|1|2|3|4))\b')
_WOMEN_PAT = re.compile(r'(?i)\b(pregnan|prenatal|antenatal|postpartum|breastfeeding|lactation|contraception|birth control|iud|pill|menstruation|periods?|pcos|endometriosis|pap(?:\s*smear)?|cervical screening|fibroids?|menopause|hot flashes?|obgyn|gyneco|pelvic pain|vaginal|uterine|ovarian)\b')
_GYN_PAT   = re.compile(r'(?i)\b(gynaecolog(?:y|ist)|gynecolog(?:y|ist)|gynae|obgyn)\b')
_PHYSIO_PAT= re.compile(r'(?i)\b(physio|physical therapy|physiotherapy|rehab|rehabilitation|range of motion|rom|strengthen(?:ing)?|stretch(?:es|ing)?|exercise plan|home exercise program|low back pain|knee pain|shoulder pain|rotator cuff|tendonitis|tendinopathy|sprain|strain|sciatica|posture|ergonomics)\b')
_NUTR_PAT  = re.compile(r'(?i)\b(dietitian|dietitan|diet(?: plan)?|nutrition|meal plan|calories|protein|carbs?|carbohydrate|fat|fiber|fibre|sodium|cholesterol|macros?|glycemic|low[-\s]?fodmap|gluten[-\s]?free|dash(?:\s*diet)?|mediterranean|keto|weight (?:loss|gain)|diabetic diet|renal diet|celiac)\b')
_NURSE_PAT = re.compile(r'(?i)\b(nurse|nursing|registered\s*nurse|r\.?n\.?)\b')
_COGN_PAT  = re.compile(r'(?i)\b(memory|attention|concentration|brain fog|cognition|executive function|adhd)\b')

# ---------------- Insurance-related detectors ----------------
_INS_NAV_PAT = re.compile(r'(?i)\b(health(?:\s*care)?\s*insur(?:ance)?|benefits?|coverage|plan|deductible|co[-\s]?pay|copay|coinsurance|oop(?:\s*max)?|out[-\s]?of[-\s]?pocket|max(?:imum)?|network|in[-\s]?network|out[-\s]?of[-\s]?network)\b')
_VOB_PAT     = re.compile(r'(?i)\b(benefits?\s*verification|verify benefits|eligibility (?:check|verification)|vob|coverage check|insurance verification)\b')
_PA_PAT      = re.compile(r'(?i)\b(prior\s*authorization|pre[-\s]?auth|precert(?:ification)?|authorization required|utilization management|peer[-\s]?to[-\s]?peer)\b')
_APPEAL_PAT  = re.compile(r'(?i)\b(denial|denied claim|appeal|reconsideration|grievance|external review)\b')
_BILLING_PAT = re.compile(r'(?i)\b(cpt|hcpcs|icd[-\s]?10|modifier|billing|coding|upcoding|unbundling|place of service|global period|bundling)\b')
_PHARM_BENEFIT_PAT = re.compile(r'(?i)\b(formulary|pbm|tier|step therapy|quantity limit|drug (?:authorization|coverage)|prior auth (?:for )?medication|copay card|specialty pharmacy)\b')
_PUBLIC_PROG_PAT   = re.compile(r'(?i)\b(medicare|medicaid|chip|cms|medigap|part\s*[abcd]\b|advantage plan|extra help|lis\b|msp\b)\b')
_COST_EST_PAT      = re.compile(r'(?i)\b(cost estimate|estimate (?:my )?out[-\s]?of[-\s]?pocket|allowed amount|price transparency|coinsurance calculation|oop estimate)\b')
_OON_PAT           = re.compile(r'(?i)\b(out[-\s]?of[-\s]?network|oon|balance bill(?:ing)?|single[-\s]?case agreement|sca\b|no surprises act)\b')
_EOB_PAT           = re.compile(r'(?i)\b(explanation of benefits|eob\b|era\b|remark code|member responsibility)\b')

# ---------------- New clinical detectors (ENT, Ortho, GI, Pulm, Radiology, Lab Tech) ----------------
_ENT_PAT    = re.compile(r'(?i)\b(ent|otolaryngolog(?:y|ist)|ear(?:ache| infection)?|otitis|hearing loss|tinnitus|vertigo|dizz(?:y|iness)|sinusitis|rhinitis|throat|tonsillitis|laryngitis|epistaxis|nosebleed|sleep apnea|snoring|deviated septum)\b')
_ORTHO_PAT  = re.compile(r'(?i)\b(orthop(?:a|e)dic|orthopedist|orthopedic surgeon|fracture|sprain|strain|dislocation|acl|meniscus|rotator cuff|shoulder dislocation|back pain|knee pain|hip pain|arthritis|tendon(?:itis|opathy)|bursitis|carpal tunnel)\b')
_GI_PAT     = re.compile(r'(?i)\b(gastroenterolog(?:y|ist)|gastroentolog|gi\b|abdominal pain|ibs\b|ibd\b|ulcer|gerd|reflux|constipation|diarrhea|nausea|vomiting|liver|hepatitis|pancreatitis|gallstones?|celiac|colonoscopy)\b')
_PULM_PAT   = re.compile(r'(?i)\b(pulmonolog(?:y|ist)|lung|asthma|copd|emphysema|bronchitis|pneumonia|shortness of breath|dyspn?ea|wheez\w*|chronic cough|inhaler|spiro(?:metry)?)\b')
_RAD_PAT    = re.compile(r'(?i)\b(radiolog(?:y|ist)|radialog(?:y|ist)|imaging report|x-?ray|ultra\s*sound|ct(?:\s*scan)?|mri|pet[-\s]?ct|contrast|gadolinium|iodinated|bi[-\s]?rads)\b')
_LABTECH_PAT= re.compile(r'(?i)\b(lab(?:orator(?:y|ies))?|lab test|phlebotom(?:y|ist)|specimen|tube|sst|edta|citrate|order of draw|hemoly[sz]is|fasting (?:blood )?test|collection|handling|turnaround time|tat\b)\b')

def _detect_specialty(query, snippet_text):
    qn = " ".join((query or "").lower().split())

    # --- Insurance-first routing ---
    if _OON_PAT.search(qn):
        return build_out_of_network_prompt(query, snippet_text)
    if _EOB_PAT.search(qn):
        return build_eob_explainer_prompt(query, snippet_text)
    if _APPEAL_PAT.search(qn):
        return build_claims_appeal_prompt(query, snippet_text)
    if _PA_PAT.search(qn):
        return build_prior_authorization_prompt(query, snippet_text)
    if _VOB_PAT.search(qn):
        return build_benefits_verification_prompt(query, snippet_text)
    if _PHARM_BENEFIT_PAT.search(qn):
        return build_pharmacy_benefits_prompt(query, snippet_text)
    if _PUBLIC_PROG_PAT.search(qn):
        return build_public_programs_prompt(query, snippet_text)
    if _COST_EST_PAT.search(qn):
        return build_cost_estimation_prompt(query, snippet_text)
    if _BILLING_PAT.search(qn):
        return build_medical_billing_coding_prompt(query, snippet_text)
    if _INS_NAV_PAT.search(qn):
        return build_insurance_navigator_prompt(query, snippet_text)

    # --- Clinical routing (with added specialties) ---
    if _ENT_PAT.search(qn):
        return build_ent_prompt(query, snippet_text)
    if _ORTHO_PAT.search(qn):
        return build_orthopedics_prompt(query, snippet_text)
    if _GI_PAT.search(qn):
        return build_gastroenterology_prompt(query, snippet_text)
    if _PULM_PAT.search(qn):
        return build_pulmonology_prompt(query, snippet_text)
    if _RAD_PAT.search(qn):
        return build_radiology_prompt(query, snippet_text)
    if _LABTECH_PAT.search(qn):
        return build_lab_technician_prompt(query, snippet_text)

    if _ONC_PAT.search(qn):
        return build_oncology_prompt(query, snippet_text)
    if _GYN_PAT.search(qn):
        return build_gynaecologist_prompt(query, snippet_text)
    if _WOMEN_PAT.search(qn):
        return build_womens_health_prompt(query, snippet_text)
    if _DENT_PAT.search(qn):
        return build_dentistry_prompt(query, snippet_text)
    if _DERM_PAT.search(qn):
        return build_dermatology_prompt(query, snippet_text)
    if _PHYSIO_PAT.search(qn):
        return build_physiotherapy_prompt(query, snippet_text)
    if _NUTR_PAT.search(qn):
        return build_dietitian_prompt(query, snippet_text)
    if _NURSE_PAT.search(qn):
        return build_nurse_prompt(query, snippet_text)
    if _MEDIT_PAT.search(qn):
        return build_meditation_prompt(query, snippet_text)
    if _COGN_PAT.search(qn) or _PSYCH_PAT.search(qn):
        return build_psychiatry_prompt(query, snippet_text)

    return None

_SELF_HARM_RE = re.compile(r"""(?ix)\b(kill\s*myself|end\s*my\s*life|suicide|self[-\s]*harm|hurt\s*myself|cut(?:ting)?\s*myself|overdos(?:e|ing)|\bod\b|i\s*want\s*to\s*die|(?:hang|poison|jump)\s*myself|die\s*by\s*suicide)\b""")
_HARM_OTHERS_RE = re.compile(r"""(?ix)\b((?:kill|murder|stab|shoot|bomb|poison|assault|violence|rape|harm|hurt|beat|strangle|choke|smother|drown|burn|arson|kidnap|abduct)\b)""")
_HC_UNITS_RE = re.compile(r"\b(?:mg|mcg|µg|g|iu|units?|mL|ml|L|mg/kg|mcg/kg|mEq|mmol/?L|µmol/?L)\b", re.I)
_HC_VITALS_RE = re.compile(
    r"(?i)\b(?:bp|blood\s*pressure)\s*\d{2,3}/\d{2,3}\b|"
    r"\b(?:hr|heart\s*rate|pulse)\s*\d{2,3}\b|"
    r"\b(?:rr|resp(?:iratory)?\s*rate)\s*\d{1,2}\b|"
    r"\b(?:spo2|o2\s*sats?|oxygen\s*saturation)\s*\d{2}%\b|"
    r"\b(?:temp(?:erature)?|t)\s*\d{2}\s*[cf]\b"
)
_HC_DOSING_RE = re.compile(
    r"\b(?:q\d{1,2}\s*(?:h|hr|hrs|d)|qod|od|bd|bid|tid|qid|qhs|qam|qpm|prn|stat|po|oral|iv|im|sc|subcut|sq|topical|transdermal|inhal(?:ed|ation)|intranasal|pr|sl|buccal)\b",
    re.I,
)
_HC_MORPH_DISEASE_RE = re.compile(
    r"\b[a-z]{3,}(?:itis|emia|osis|oma|opathy|algia|uria|rrhea|neuropathy|dermatitis|carditis|nephritis|hepatitis|arthrit(?:is)?|myopathy|cardiomyopathy|encephalopathy)\b",
    re.I,
)
_HC_MORPH_PROC_RE = re.compile(
    r"\b[a-z]{3,}(?:ectomy|otomy|plasty|scopy|graphy|gram|stomy|centesis|ablation|biopsy|pexy|lysis|desis|arthroplasty|catheterization|angioplasty|transplant(?:ation)?)\b",
    re.I,
)
_HC_DRUG_SUFFIX_RE = re.compile(
    r"\b[a-z]{3,}(?:pril|sartan|olol|statin|azole|cycline|floxacin|cillin|mycin|prazole|tidine|caine|dronate|zide|mide|gliptin|gliflozin|glitazone|mab|nib|limus|avir|ovir|mol)\b",
    re.I,
)
_HC_LAB_RE = re.compile(
    r"\b(?:wbc|rbc|hgb|hct|hba1c|a1c|tsh|t3|t4|ldl|hdl|tg|alt|ast|alp|ggt|crp|esr|inr|ptt|pt|troponin|creatinine|bun|egfr|cbc|cmp|lfts?|bilirubin|d[- ]?dimer|psa|cea|afp|ca[- ]?125|her2|brca)\b|"
    r"\b(?:mg/dl|mmol/l|meq/l|u/l|iu/l|ng/ml|pg/ml)\b",
    re.I,
)
_HC_ANAT_RE = re.compile(
    r"\b(?:cardio|coronary|neuro|pulmo|renal|hepatic|derma|gastro|endocrine|thyroid|pancrea|colon|stomach|liver|kidney|lung|heart|brain|skin|bone|muscle|spine|ocular|optic|otitis|sinus|ear|nose|throat|prostate|breast|ovary|uterus|cervix|test(?:is|es)|adrenal|pituitary|spleen|gallbladder)\w*\b",
    re.I,
)
_HC_BODY_RE = re.compile(
    r"\b("
    r"head|scalp|skull|face|eye|eyes|eyelid|eyebrow|eyelash|pupil|iris|ear|ears|eardrum|nose|nostril|sinus|mouth|lip|tongue|tooth|teeth|gum|jaw|cheek|palate|throat|tonsil|larynx|voice box|trachea|windpipe|neck|nape|"
    r"shoulder|clavicle|collarbone|scapula|arm|upper arm|elbow|forearm|wrist|hand|palm|finger|thumb|nail|"
    r"chest|rib|sternum|breast|axilla|armpit|back|spine|spinal cord|vertebra|"
    r"abdomen|belly|stomach|navel|umbilicus|flank|groin|pelvis|hip|buttock|"
    r"genital|penis|scrotum|testicle|testis|vagina|vulva|uterus|cervix|ovary|"
    r"thigh|knee|patella|leg|calf|ankle|heel|foot|feet|toe|toes|sole|"
    r"brain|cerebellum|cerebrum|nerve|tendon|ligament|cartilage|muscle|fascia|marrow|bone|"
    r"artery|vein|capillary|blood|plasma|platelet|red blood cell|white blood cell|"
    r"lung|bronchus|bronchi|alveoli|diaphragm|"
    r"heart|atrium|ventricle|aorta|valve|"
    r"liver|kidney|spleen|pancreas|gallbladder|bile duct|"
    r"bladder|urethra|prostate|colon|rectum|anus|"
    r"thyroid|parathyroid|adrenal|pituitary|hypothalamus|ovaries|testes|"
    r"skin|dermis|epidermis|hair|follicle|sweat gland|sebaceous gland|"
    r"organ|tissue|cell"
    r")\b",
    re.I,
)
_HC_DOC_RE = re.compile(
    r"\b(?:hpi|ros|pmh|psh|fh|sh|a/p|assessment|plan|impression|progress note|operative note|op note|discharge (?:note|summary)|clinical notes?)\b",
    re.I,
)
_HC_ACRONYM_RE = re.compile(
    r"\b(?:cpr|cabg|pci|ecg|ekg|mi|stemi|nstemi|copd|chf|hf|tia|dvt|pe|cad|dm|htn|hld|ckd|esrd|uti|bph|psa|ibs|ibd|gerd|icu|ed|er|mri|ct|aed|abg|cxr|lft|cmp|cbc)\b",
    re.I,
)
_HC_GENERAL_RE = re.compile(
    r"(?i)\b("
    r"symptom|symptoms|signs|diagnosis|diagnose|screen(?:ing)?|risk\s*factors?|prevention|prognosis|management|treatment|therapy|therapies|"
    r"procedure|surgery|operation|first aid|resuscitation|bls|als|aed|defibrillat(?:or|ion)|cpr|"
    r"biomarker|tumor\s*marker|genetic\s*test|imaging|x[- ]?ray|ultrasound|ct|mri|"
    r"vaccine|immunization|side\s*effects?|contraindications?|precautions?|dos(?:e|ing)|mg/kg|tablet|capsule|syrup|"
    r"concussion|fracture|sprain|hypertension|diabetes|asthma|cancer|infection|antibiotic|antiviral|analgesic|chemotherapy|radiation"
    r")\b"
)
_NON_TECH_RE = re.compile(r"\b(?:python|javascript|java|sql|docker|kubernetes|api|sdk|gpu|model|function|class|bug|deployment|server|database|regex)\b", re.I)
_NON_FIN_RE = re.compile(r"\b(?:stock|crypto|bitcoin|forex|interest rate|mortgage|tax|budget|invoice|revenue|profit|earnings)\b", re.I)
_NON_MISC_RE = re.compile(r"\b(?:recipe|cook|bake|hotel|flight|travel|itinerary|football|soccer|nba|fifa|gaming|console|movie|tickets?|concert)\b", re.I)

def preprocess_text(text: str) -> str:
    text = html.unescape(text or "")
    text = text.strip()
    text = re.sub(r"\s+", " ", text)
    if not re.match(r".*[.?!]$", text):
        text += "?"
    return text

def _healthcare_heuristic_label(text: str) -> str:
    t = (text or "")
    if _HC_BODY_RE.search(t):
        return "health"
    pos = 0
    pos += 2 * len(_HC_UNITS_RE.findall(t))
    pos += 3 * len(_HC_VITALS_RE.findall(t))
    pos += 2 * len(_HC_DOSING_RE.findall(t))
    pos += 2 * len(_HC_MORPH_DISEASE_RE.findall(t))
    pos += 3 * len(_HC_MORPH_PROC_RE.findall(t))
    pos += 3 * len(_HC_DRUG_SUFFIX_RE.findall(t))
    pos += 2 * len(_HC_LAB_RE.findall(t))
    pos += 1 * len(_HC_ANAT_RE.findall(t))
    pos += 3 * len(_HC_DOC_RE.findall(t))
    pos += 4 * len(_HC_ACRONYM_RE.findall(t))
    pos += 3 * len(_HC_GENERAL_RE.findall(t))
    if pos > 30: pos = 30
    neg = 0
    neg += 3 * len(_NON_TECH_RE.findall(t))
    neg += 2 * len(_NON_FIN_RE.findall(t))
    neg += 1 * len(_NON_MISC_RE.findall(t))
    if neg > 20: neg = 20
    if pos >= 6 and (pos - neg) >= 3:
        return "health"
    if neg >= 6 and pos <= 3:
        return "non"
    return "uncertain"

def _raw_classify(prompt: str) -> str:
    result = generator(
        prompt,
        max_new_tokens=1024,
        repetition_penalty=1.0,
        early_stopping=True,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.pad_token_id,
        temperature=0.0,
        do_sample=False,
        top_p=1.0,
    )
    out = result[0]["generated_text"]
    if out.startswith(prompt):
        out = out[len(prompt):]
    return out.strip()

def is_healthcare_question(query: str) -> bool:
    q = preprocess_text(query)
    if _HC_BODY_RE.search(q):
        return True
    label = _healthcare_heuristic_label(q)
    if label == "health":
        return True
    if label == "non":
        return False
    cls_prompt = (
        "You are a precise, literal classifier. "
        "Determine if the user's question is PRIMARILY about healthcare/medicine, including: "
        "human diseases, symptoms, diagnosis, tests, treatments, medications, procedures, "
        "clinical guidelines, mental health, nutrition as it relates to health, public health, "
        "or healthcare systems and delivery. If YES, output exactly: YES. If NO, output exactly: NO.\n\n"
        f"Question: {q}\n"
        "Answer (YES or NO only):"
    )
    try:
        out = _raw_classify(cls_prompt).upper()
    except Exception:
        return label != "non"
    return out.startswith("YES")

def _self_harm_support_response(query: str) -> str:
    p = (
        "You are a compassionate mental-health support assistant. The user may mention self-harm. "
        "Write a short, generic, location-agnostic response that includes: "
        "1) an empathetic opening, 2) immediate safety guidance to contact local emergency services if at risk, "
        "3) advice to reach a local suicide/crisis hotline without listing specific phone numbers or URLs, "
        "4) one brief breathing exercise and a 3–5 step mini-meditation, "
        "5) encouragement to seek professional help and to reach out to someone they trust. "
        "Keep it under 150 words, use plain language and second person, and avoid links, numbers, or country names."
        f"\n\nUser: {preprocess_text(query)}\nResponse:"
    )
    try:
        raw = generate(p, max_new_tokens=300, temperature=0.0)
    except TypeError:
        raw = generate(p)
    txt = _safe_text(raw, query)
    return txt if txt else "If you are in immediate danger, contact your local emergency number now. You deserve support; consider speaking with a trusted person and a local crisis hotline. Try slow breathing: inhale 4, hold 4, exhale 4, hold 4, for a minute. Sit comfortably and notice five things you see, four you feel, three you hear, two you smell, and one you taste. A mental health professional can help—please reach out today."

def guard_and_build_prompt(query, snippet_text):
    q = (query or "")
    qn = " ".join(q.lower().split())
    if _SELF_HARM_RE.search(qn):
        return "SELF_HARM_SUPPORT"
    if _HARM_OTHERS_RE.search(qn) or re.search(r"(?i)\b(kill|murder|stab|shoot(?:\s*up)?|bomb|poison|assault|violence|rape|harm|hurt|beat|strangle|choke|smother|drown|burn|arson|kidnap|abduct)\b", qn):
        return "Please ask only healthcare question."
    if not is_healthcare_question(q):
        return "Please ask only healthcare question."
    sp = None
    try:
        sp = _detect_specialty(q, snippet_text)
    except Exception:
        sp = None
    if sp:
        return sp
    return _rephrase_assist_prompt(q)

def _strip_meta_overview_speak(text: str) -> str:
    if not text:
        return text
    META_PATTERNS = [
        r'(?i)\bwrite a (?:concise|brief|short)\b.*\bprofessional overview\b',
        r'(?i)\bhighly professional overview\b',
        r'(?i)\banswer(?:s|ing)? (?:the )?user(?:\'s)? question directly\b',
        r'(?i)\breturn (?:just|only) the corrected text\b',
        r'(?i)\bonly fix grammar\b',
        r'(?i)\bkeep .*? exactly the same\b',
        r'(?i)\bthe original text (?:was|is) already (?:grammatically )?correct\b',
        r'(?i)\bgrammar (?:was|is) already correct\b',
        r'(?i)\bno (?:changes|edits) (?:were|are) needed\b',
        r'(?i)\b(as|you are) (?:an?|the)\s+\w+(?:\s\w+){0,4}\s+(assistant|editor|clinician|doctor|pharmacist|bot)\b',
        r'(?i)\bthis (?:overview|answer|response)\b',
        r'(?i)\bthe (?:overview|answer|response)\b',
        r'(?i)\bit clearly states\b',
        r'(?i)\bit emphasizes\b',
        r'(?i)\boverall,\s*(?:this|the)\s+(?:overview|answer|response)\b',
        r'(?i)\bno steps\b',
        r'(?i)\bplease use proper (?:spelling and grammar|spelling|grammar)\b'
    ]
    meta_re = [re.compile(p) for p in META_PATTERNS]
    parts = re.split(r'(?<=[.!?])\s+|\n+', text.strip())
    kept = []
    for s in parts:
        ss = s.strip()
        if not ss:
            continue
        if any(r.search(ss) for r in meta_re):
            continue
        kept.append(ss)
    sep = '\n' if '\n' in text else ' '
    out = sep.join(kept).strip()
    return out

def clean_output(text: str) -> str:
    if not text:
        return ""
    t = text
    t = re.sub(r"https?://\S+|www\.\S+", "", t)
    t = re.sub(r"<script[\s\S]*?</script>", "", t)
    t = re.sub(r"```.*?```", "", t, flags=re.DOTALL)
    garbage_regex = re.compile(r"(?i)(note:|only in english|all rights reserved|opyright|do not publish|generated.*?ai|assistant.*?opyright)")
    meta_regex = re.compile(r"(?i)\b(sql|database|query|table|column|row|select|insert|update|delete|schema|python|javascript|function|class|script|module|api|sdk|token|prompt|temperature|model|parser|syntax)\b")
    verb_regex = re.compile(r"\b(am|is|are|was|were|be|being|been|have|has|had|do|does|did|can|could|may|might|shall|should|will|would|must|treat|cause|prevent|increase|reduce|check|monitor|take|stop|start|affect|lower|raise|control|measure|diagnose|screen|advise|avoid|drink|eat|exercise)\b", re.I)
    def _is_heading_like(s):
        if not s:
            return False
        w = s.strip()
        if re.search(r"[.?!]$", w):
            return False
        words = w.split()
        if len(words) <= 2:
            return True
        if len(words) <= 8 and w.isupper():
            return True
        cap_ratio = sum(1 for x in words if x[:1].isupper()) / max(1, len(words))
        return len(words) <= 8 and cap_ratio > 0.6
    def _is_keyword_list(s):
        return s.count(",") >= 3 and not verb_regex.search(s or "")
    cleaned_lines, seen = [], set()
    for ln in t.splitlines():
        raw = ln.strip()
        if not raw:
            if cleaned_lines and cleaned_lines[-1] != "":
                cleaned_lines.append("")
            continue
        if garbage_regex.search(raw):
            continue
        if meta_regex.search(raw):
            continue
        if re.match(r"^\s*#{1,6}\s+\S", raw):
            continue
        if _is_heading_like(raw):
            continue
        if _is_keyword_list(raw):
            continue
        if re.search(r"(?i)\b(reader interactions|report a problem|how do i cite|citation|subscribe|sign in)\b", raw):
            continue
        if re.search(r"\b\w+\.(com|org|net|io|edu)\b", raw):
            continue
        if re.search(r"(?i)\b(apa|mla|chicago)\b", raw):
            continue
        if re.search(r"(?i)\b(you have reached your limit|additional views|start over)\b", raw):
            continue
        key = re.sub(r"\W+", "", raw.lower())
        if key in seen:
            continue
        seen.add(key)
        cleaned_lines.append(raw)
    cleaned = "\n".join(cleaned_lines)
    cleaned = re.sub(r"\n{3,}", "\n\n", cleaned)
    cleaned = "\n".join(re.sub(r"[ \t]{2,}", " ", x).strip() for x in cleaned.split("\n"))
    return cleaned.strip()

def _strip_echo(answer: str, query: str) -> str:
    q = (query or "").strip().lower()
    a = (answer or "").lstrip()
    if q and a.lower().startswith(q):
        a = a[len(query):].lstrip(" \n:-")
    a_lines = [ln for ln in a.splitlines() if ln.strip().lower() != q]
    return "\n".join(a_lines).strip()

def _normalize(text):
    text = re.sub(r"\r\n?", "\n", text or "")
    text = re.sub(r"\n{3,}", "\n\n", text)
    return text.strip()

def _html_wrap(answer: str) -> str:
    return f"""
    <div style="white-space: pre-wrap; font-family: Inter, ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto; font-size: 16px; line-height: 1.75; color:#0f172a; max-width: 800px; margin: 8px auto 2px auto; padding: 18px 20px; background: #ffffff; border: 1px solid #e5e7eb; border-radius: 14px;">
    {html.escape(answer)}
    </div>
    """

def _strip_code_blocks(text: str) -> str:
    if not text:
        return text
    text = re.sub(r"<code[\s\S]*?</code>", "", text)
    text = re.sub(r"```.*?```", "", text, flags=re.DOTALL)
    text = re.sub(r"^\s*(import |from |def |class |#\!|#\s|if __name__ == ['\"]__main__['\"]:).*$", "", text, flags=re.MULTILINE)
    text = re.sub(r"\n{3,}", "\n\n", text).strip()
    return text

def _looks_like_code_explanation(text: str) -> bool:
    if not text:
        return False
    return bool(re.search(r"(?i)\b(this code|the (?:code|function|script|class)|python|in code|the snippet)\b", text))

def _looks_like_nlp_explanation(text: str) -> bool:
    if not text:
        return False
    return bool(re.search(r"(?i)\b(spacy|auxpass|dependency|pos tag|token(?:ization)?|lemma|parse tree|syntax|fronting|matcher|phrase\s*matcher|pipeline|nlp model|linguistic[s]?)\b", text))

def _repair_med_prompt(query: str, snippet_text: str) -> str:
    return _rephrase_assist_prompt(query)

def _safe_text(raw: str, query: str) -> str:
    if not raw:
        return ""
    raw = _cut_at_end_token(raw)
    txt = _strip_code_blocks(raw)
    txt = _strip_echo(txt, query)
    txt = _normalize(txt)
    return txt.strip() or raw.strip()

_DOSE_PHRASE_RE = re.compile(r"(?i)(?<![A-Za-z])\d+(?:\.\d+)?\s*(?:mcg|µg|mg|g|iu|units?|mL|ml|L)(?:\s*(?:/\s*(?:kg|m²|m2|day|d|dose)))?")
_FREQ_RE = re.compile(r"(?i)\b(q\d+\s*(?:h|hr|hrs)|q\d{1,2}h|once daily|twice daily|every\s+\d+\s*(?:hours?|days?)|(?:od|bd|bid|tid|qid|qhs|qam|qpm)\b)")
_ROUTE_RE = re.compile(r"(?i)\b(po|oral|sublingual|buccal|iv|intravenous|im|intramuscular|sc|subcut(?:aneous)?|topical|transdermal|inhal(?:ation|ed)?|intranasal|nasal|ophthalmic|otic|rectal|pr)\b")
_CONC_RE = re.compile(r"(?i)\b(?:mcg|µg|mg)\s*/\s*(?:mL|L)\b")
_UNDER2_YEARS_RE = re.compile(r"(?i)\b(?:under|less\s*than|younger\s*than|<)\s*2\s*years?\b|\b1\s*(?:year|yr|yo|y/o)\b")
_UNDER2_MONTHS_RE = re.compile(r"(?i)\b(\d{1,2})\s*(?:months?|mos?|mths?|m/o)\b")
_INFANT_TERMS_RE = re.compile(r"(?i)\b(newborn|neonate|infant)\b")
_QUERY_AGE_RE = re.compile(r"(?i)\b(\d{1,2})\s*(?:-?\s*(?:year|yr)\s*old|years?|yrs?|yo|y/o)\b")
_RANGE_YEARS_RE = re.compile(r"(?i)\b(\d{1,2})\s*(?:–|-|—|to)\s*(\d{1,2})\s*(?:years?|yrs?)\b")
_UNDER_OVER_RE = re.compile(r"(?i)\b(under|over)\s*(\d{1,2})\s*(?:years?|yrs?)\b")
_CHILD_CONTEXT_RE = re.compile(r"(?i)\b(child|children|kid|kids|baby|infant|toddler|newborn|neonate)\b")

def _mentions_under2(text: str) -> bool:
    if not text:
        return False
    if _UNDER2_YEARS_RE.search(text) or _INFANT_TERMS_RE.search(text):
        return True
    for m in _UNDER2_MONTHS_RE.findall(text):
        try:
            if int(m) < 24:
                return True
        except ValueError:
            pass
    return False

_AGE_YEARS_RE = re.compile(r'(?i)\b(\d+(?:\.\d+)?)\s*(?:years?|yrs?|y)\b')
_AGE_YEARS_OLD_ONLY_RE = re.compile(r'(?i)\b(\d+(?:\.\d+)?)\s*(?:-?\s*(?:year|yr))\s*-?\s*old\b')
_AGE_YO_RE = re.compile(r'(?i)\b(\d+(?:\.\d+)?)\s*(?:yo|y/o)\b')

_AGE_MONTHS_OLD_RE = re.compile(r'(?i)\b(\d+(?:\.\d+)?)\s*(?:-?\s*(?:months?|mos?|mths?))\s*-?\s*old\b')
_AGE_MONTHS_MO_SLASH_RE = re.compile(r'(?i)\b(\d+(?:\.\d+)?)\s*m/o\b')
_AGE_MONTHS_WITH_AGE_PREFIX_RE = re.compile(r'(?i)\bage\s*(?:is|:)?\s*(\d+(?:\.\d+)?)\s*(?:months?|mos?|mths?)\b')

def _extract_age_months_strict(text: str):
    t = (text or "").lower()
    m = _AGE_MONTHS_OLD_RE.search(t)
    if m:
        try:
            return float(m.group(1).replace(',', '.'))
        except Exception:
            pass
    m = _AGE_MONTHS_MO_SLASH_RE.search(t)
    if m:
        try:
            return float(m.group(1).replace(',', '.'))
        except Exception:
            pass
    m = _AGE_MONTHS_WITH_AGE_PREFIX_RE.search(t)
    if m:
        try:
            return float(m.group(1).replace(',', '.'))
        except Exception:
            pass
    return None

def _is_under_two_from_text(text: str) -> bool:
    t = (text or "").lower()

    m = _AGE_YEARS_RE.search(t) or _AGE_YEARS_OLD_ONLY_RE.search(t) or _AGE_YO_RE.search(t)
    if m:
        try:
            return float(m.group(1).replace(',', '.')) < 5
        except Exception:
            pass

    mm = _extract_age_months_strict(t)
    if mm is not None:
        try:
            return float(mm) < 60.0
        except Exception:
            pass

    return False


def _extract_age_from_query(text: str):
    if not text:
        return None
    m = _QUERY_AGE_RE.search(text)
    if not m:
        return None
    try:
        return int(m.group(1))
    except Exception:
        return None

def _age_ranges_in_sentence(s: str):
    ranges = []
    for a, b in _RANGE_YEARS_RE.findall(s):
        try:
            lo = int(a); hi = int(b)
            if lo <= hi:
                ranges.append(("range", lo, hi))
        except Exception:
            pass
    m = _UNDER_OVER_RE.search(s)
    if m:
        kind = m.group(1).lower()
        try:
            n = int(m.group(2))
            if kind == "under":
                ranges.append(("under", n))
            elif kind == "over":
                ranges.append(("over", n))
        except Exception:
            pass
    singles = []
    for g in _QUERY_AGE_RE.findall(s):
        try:
            singles.append(int(g[0] if isinstance(g, tuple) else g))
        except Exception:
            pass
    return ranges, singles

def _filter_age_mismatch(text: str, query: str) -> str:
    age = _extract_age_from_query(query or "")
    if not age:
        return text
    blocks = re.split(r'(?:\n\s*\n)+', text.strip())
    kept_blocks = []
    for b in blocks:
        sents = re.split(r'(?<=[.!?])\s+', b.strip())
        kept_sents = []
        for s in sents:
            if not s.strip():
                continue
            if not re.search(r'(?i)\b(child|children|kid|kids|aged|age|years?\s*old|yrs?|yo|y/o)\b', s):
                kept_sents.append(s)
                continue
            ranges, singles = _age_ranges_in_sentence(s)
            if not ranges and not singles:
                kept_sents.append(s)
                continue
            ok = False
            for r in ranges:
                if r[0] == "range" and r[1] <= age <= r[2]:
                    ok = True
                if r[0] == "under" and age < r[1]:
                    ok = True
                if r[0] == "over" and age > r[1]:
                    ok = True
            if age in singles:
                ok = True
            if ok:
                kept_sents.append(s)
        kb = " ".join(kept_sents).strip()
        if kb:
            kept_blocks.append(kb)
    return "\n\n".join(kept_blocks).strip() if kept_blocks else text

def dose_verification_filter(text: str) -> str:
    if text is None:
        return ""
    t = text
    patterns = [
        r'(?is)\b(?:dose|dosage)[^.?\n]*?(?:=|:)[^.?\n]*?(?:x|×|\*)[^.?\n]*?(?:/|÷)\s*(?:100|1000)\b[^.?\n]*[.?!]?',
        r'(?is)\b(?:weight|kg)[^.?\n]*?(?:x|×|\*)[^.?\n]*?\b(?:age|years?|yrs?|yo|y/o)\b[^.?\n]*?(?:/|÷)\s*(?:100|1000)\b[^.?\n]*[.?!]?',
        r'(?is)\b(?:age|years?|yrs?|yo|y/o)[^.?\n]*?(?:x|×|\*)[^.?\n]*?\b(?:weight|kg)\b[^.?\n]*?(?:/|÷)\s*(?:100|1000)\b[^.?\n]*[.?!]?',
        r'(?im)^.*for example.*?(?:/|÷)\s*(?:100|1000)\b.*$'
    ]
    for p in patterns:
        t = re.sub(p, '', t)
    t = re.sub(r'\n{3,}', '\n\n', t).strip()
    return t

def _strip_sentence_initial_yes(text: str) -> str:
    if not text:
        return text
    return re.sub(r'(?mi)(^|(?<=[.!?]))\s*(?:yes,\s*|\?+,?\s*)', r'\1', text)

_list_item_re = re.compile(r'^\s*(?:\d+[.)]|[-*•])\s+(.*)$')

def _is_list_block(block: str) -> bool:
    lines = [ln for ln in block.splitlines() if ln.strip()]
    if not lines:
        return False
    return all(_list_item_re.match(ln) for ln in lines)

def _norm_sentence(s: str) -> str:
    s = s.strip()
    s = _list_item_re.sub(r'\1', s)
    s = re.sub(r'^[\'"“”‘’]+|[\'"“”‘’]+$', '', s)
    s = s.rstrip(' .;:!?')
    s = re.sub(r"[^\w\s]", ' ', s)
    s = re.sub(r'\b(the|a|an|any|your|their|his|her|its|our)\b', ' ', s, flags=re.I)
    s = re.sub(r'\s+', ' ', s)
    return s.lower().strip()

def _sentences_from_paragraph(block: str):
    parts = re.split(r'(?<=[.!?])\s+', block.strip())
    return [p for p in parts if p.strip()]

def _items_from_list(block: str):
    items = []
    for ln in block.splitlines():
        if not ln.strip():
            continue
        m = _list_item_re.match(ln)
        items.append((m.group(1) if m else ln).strip())
    return items

try:
    from rapidfuzz import fuzz as _rf_fuzz
except Exception:
    _rf_fuzz = None

def _similarity_ratio(a: str, b: str) -> float:
    if _rf_fuzz:
        try:
            s1 = _rf_fuzz.token_sort_ratio(a, b) / 100.0
            s2 = _rf_fuzz.token_set_ratio(a, b) / 100.0
            s3 = _rf_fuzz.partial_ratio(a, b) / 100.0
            s4 = _rf_fuzz.ratio(a, b) / 100.0
            return max(s1, s2, s3, s4)
        except Exception:
            pass
    return difflib.SequenceMatcher(None, a, b).ratio()

def _dedupe_repeated_content(text: str, sent_threshold: float = 0.88, para_threshold: float = 0.9) -> str:
    if not text:
        return text
    blocks = [b for b in re.split(r'(?:\n\s*\n)+', text.strip()) if b.strip()]
    kept_blocks = []
    seen_sents_norm = []
    for block in blocks:
        if _is_list_block(block):
            items = _items_from_list(block)
            new_items, norm_items = [], []
            for it in items:
                n = _norm_sentence(it)
                if any(_similarity_ratio(n, m) >= sent_threshold for m in norm_items):
                    continue
                if any(_similarity_ratio(n, m) >= sent_threshold for m in seen_sents_norm):
                    continue
                new_items.append(it)
                norm_items.append(n)
                seen_sents_norm.append(n)
            if new_items:
                kept_blocks.append("\n".join(f"{x}" for x in new_items))
            continue
        sents = _sentences_from_paragraph(block)
        new_sents = []
        local_norms = []
        for s in sents:
            n = _norm_sentence(s)
            if any(_similarity_ratio(n, _norm_sentence(prev)) >= sent_threshold for prev in new_sents):
                continue
            if any(_similarity_ratio(n, m) >= sent_threshold for m in seen_sents_norm):
                continue
            new_sents.append(s)
            local_norms.append(n)
        para = " ".join(new_sents).strip()
        if not para:
            continue
        if any(_similarity_ratio(_norm_sentence(para), _norm_sentence(pb)) >= para_threshold for pb in kept_blocks):
            continue
        kept_blocks.append(para)
    if not kept_blocks:
        return text
    return "\n\n".join(kept_blocks).strip()

_MIX_VERBS = re.compile(r"(?i)\b(mix|mixed|mixing|dilute|diluted|diluting|combine|combined|stir|stirred|stirring|administer(?:ed)?\s+with|take(?:n)?\s+with|give(?:n)?\s+with)\b")
_MILK_JUICE = re.compile(r"(?i)\b(milk|breast\s*milk|formula|fruit\s*juice|juice|orange\s*juice|apple\s*juice|grape\s*juice|grapefruit\s*juice)\b")

def _enforce_no_milk_juice(text: str) -> str:
    if not text:
        return text
    blocks = re.split(r'(?:\n\s*\n)+', text.strip())
    changed = False
    new_blocks = []
    for b in blocks:
        if _is_list_block(b):
            items = _items_from_list(b)
            kept = []
            for it in items:
                s = it.strip()
                if _MIX_VERBS.search(s) and _MILK_JUICE.search(s):
                    changed = True
                    continue
                kept.append(it)
            if kept:
                new_blocks.append("\n".join(f"{x}" for x in kept))
            continue
        sents = _sentences_from_paragraph(b)
        kept_sents = []
        for s in sents:
            if _MIX_VERBS.search(s) and _MILK_JUICE.search(s):
                changed = True
                continue
            kept_sents.append(s)
        if kept_sents:
            new_blocks.append(" ".join(kept_sents))
    out = "\n\n".join(new_blocks).strip()
    if changed and "Safety note: Do not mix medicines with milk or fruit juice." not in out:
        caution = "Safety note: Do not mix medicines with milk or fruit juice. Unless a clinician or the product label explicitly permits it, use plain water for administration."
        out = (caution + "\n\n" + out).strip()
    return out if out else text

def _age_is_two_or_under(text: str) -> bool:
    t = (text or "").lower()
    if re.search(r'\b(under|less\s*than|below)\s*(?:or\s*equal\s*to\s*)?(?:2|two)\s*(?:years?|yrs?)\b', t):
        return True
    if re.search(r'\b(?:≤|<=)\s*2\s*(?:years?|yrs?)\b', t):
        return True
    if re.search(r'\b(?:2|two)[-\s]?(?:year|yr)\s*old\b', t):
        return True
    if re.search(r'\b(?:2|two)\s*(?:yo|y/o|yrs?\s*old|years?\s*old)\b', t):
        return True
    if re.search(r'\bage\s*(?:is|:)?\s*(?:2|two)\b', t):
        return True
    for m in re.findall(r'\b(\d{1,3})\s*months?\b', t):
        try:
            if int(m) <= 24:
                return True
        except ValueError:
            pass
    if re.search(r'\b(neonate|newborn|infant)\b', t):
        return True
    return False

def _maybe_add_under2_caution(text: str, query: str) -> str:
    if not _is_under_two_from_text(query):
        return text
    caution = (
        "Caution (<5 years): Dosing and administration should be directed by a clinician. "
        "Use the supplied oral syringe, verify product strength (mg/mL), and avoid self-dosing without professional advice. "
        "It is not advised to administer any medicine to children under 5 years of age unless specifically prescribed and supervised.\n\n"
        "We value health of your child and therefore we do not recommend any medicine for them other than Panadol drops and Panadol Liquid that can be used for mild to moderate pain in babies over one month old.\n\n"
        "Panadol drops: Dose: 10–15 mg/kg per dose every 4–6 hours; Max: 75 mg/kg/day. Use the supplied oral syringe and verify the bottle strength (mg/mL).\n"
        "Panadol suspension: Dose: 10–15 mg/kg per dose every 4–6 hours; Max: 75 mg/kg/day. Check the concentration (e.g., mg/5 mL) to measure the correct volume.\n\n"
        "For other health issues, consult a Pediatrician."
    )
    return caution

def _apply_general_safety_overrides(text: str, query: str) -> str:
    t = _enforce_no_milk_juice(text)
    t = _maybe_add_under2_caution(text=t, query=query)
    t = _dedupe_repeated_content(t)
    return t

_LEADIN_RE = re.compile(
    r'^\s*(?:how to|steps? to|procedure for|management of|'
    r'diagnosis of|evaluation of|assessment of|first aid for|care for|'
    r'what to do for|work[-\s]?up (?:of|for)|approach to)\s+',
    flags=re.IGNORECASE
)

def _extract_topic(q: str) -> str:
    topic = _LEADIN_RE.sub('', q or '').strip()
    return topic.rstrip('?.:;,')

_PROC_PAT = re.compile(r"(?i)\b(steps?|procedure|process|how to|first aid|resuscitation|cpr|aed|bls|als|choking|airway|breathing|circulation|bleeding control|wound care|burns?|sprain|strain|immobilization|bandag(?:e|ing)|recovery position|heimlich|abdominal thrusts)\b")

def _is_procedure_process(q: str) -> bool:
    return bool(_PROC_PAT.search(q or ""))

def _rephrase_assist_prompt(query: str) -> str:
    topic = _extract_topic(query)
    focus = f" Focus your overview on {topic}." if topic else ""
    return (
        "You are a senior clinical writer. Provide a concise, highly professional overview that answers the user's question directly."
        " Write EXACTLY ONE cohesive paragraph (90–140 words), in clear, neutral medical English."
        " Use complete sentences, start with a capital letter, and end with a period."
        " Avoid lists, bullets, headings, markdown, citations, or disclaimers." + focus +
        f"\n\nUser input: {query}\nCoach:"
    )

def _strip_role_artifacts(text: str) -> str:
    if not text:
        return text
    t = text
    t = re.sub(r'(?mi)^\s*question\s*:\s*.*$', '', t)
    t = re.sub(r'(?mi)^\s*q\s*:\s*.*$', '', t)
    t = re.sub(r'(?mi)^\s*answer\s*:\s*', '', t)
    t = re.sub(r'(?mi)^\s*a\s*:\s*', '', t)
    t = re.sub(r'\b(?:a|an)\s*:\s*(?:assistant|user)\b', '', t, flags=re.I)
    t = re.sub(r'(?mi)^\s*(?:assistant|user)\s*:\s*', '', t)
    t = re.sub(r'\s*:\s*(?:assistant|user)\b', '', t, flags=re.I)
    t = re.sub(r'\(\s*(?:assistant|user)\s*\)', '', t, flags=re.I)
    t = re.sub(r'(?mi)^\s*(?:coach|doctor|dr)\s*:\s*.*$', '', t)
    t = re.sub(r'(?mi)^\s*user\s*input\s*:\s*.*$', '', t)
    t = re.sub(r'\s+([,.;:!?])', r'\1', t)
    t = re.sub(r'[ \t]{2,}', ' ', t)
    t = re.sub(r'\n{3,}', '\n\n', t)
    return t.strip()

def _normalize_numbered_steps(text: str) -> str:
    if not text:
        return text
    lines = text.splitlines()
    numbered_re = re.compile(r'^\s*(\d+)[\.)]\s+(.*)$')
    bullet_re = re.compile(r'^\s*[-*•]\s+(.*)$')
    step_colon_re = re.compile(r'^\s*[A-Z][^:\n]{1,120}:\s*.*$')
    out_lines = []
    in_list = False
    n = 1
    for i, ln in enumerate(lines):
        stripped = ln.strip()
        m_num = numbered_re.match(ln)
        m_bul = bullet_re.match(ln)
        if m_num:
            if not in_list:
                in_list = True
                n = 1
            out_lines.append(f"{n}. {m_num.group(2).strip()}")
            n += 1
        elif in_list and m_bul:
            text_part = m_bul.group(1).strip()
            out_lines.append(f"{n}. {text_part}")
            n += 1
        elif in_list and step_colon_re.match(ln):
            out_lines.append(stripped)
        elif stripped == "":
            out_lines.append(ln)
        else:
            out_lines.append(ln)
            in_list = False
    return "\n".join(out_lines).strip()

def _organize_paragraphs(text: str) -> str:
    if not text:
        return text
    lines = text.splitlines()
    merged = []
    for i, ln in enumerate(lines):
        cur = ln.rstrip()
        if merged:
            prev = merged[-1]
            if prev and not re.search(r'[.!?]"?\s*$', prev) and cur and cur[:1].islower():
                merged[-1] = prev.rstrip() + " " + cur.lstrip()
                continue
        merged.append(cur)
    t = "\n".join(merged)
    t = re.sub(r'[ \t]+\n', '\n', t)
    t = re.sub(r'\n{3,}', '\n\n', t)
    blocks = [b.strip() for b in re.split(r'(?:\n\s*\n)+', t.strip()) if b.strip()]
    normalized = []
    for b in blocks:
        b = re.sub(r'\s{2,}', ' ', b)
        normalized.append(b.strip())
    return "\n\n".join(normalized).strip()

def _strip_inline_enumerators(text: str) -> str:
    if not text:
        return text
    enum_token = re.compile(r'(?:(?<=\s)|^)\(?\d{1,2}[\.)](?=\s)')
    paras = re.split(r'(?:\n\s*\n)+', text.strip())
    cleaned = []
    for p in paras:
        if _is_list_block(p):
            cleaned.append(p)
            continue
        q = enum_token.sub('', p)
        q = re.sub(r'\s{2,}', ' ', q).strip()
        cleaned.append(q)
    return "\n\n".join(cleaned).strip()

try:
    from rapidfuzz import process as _rf_process, fuzz as _rf_fuzz2
except Exception:
    _rf_process, _rf_fuzz2 = None, None

try:
    from wordfreq import top_n_list as _wf_top_n, zipf_frequency as _wf_zipf
except Exception:
    _wf_top_n, _wf_zipf = None, None

_TRUSTED_VOCAB = None
_word_re = re.compile(r"[A-Za-z][A-Za-z'-]*")
INTENT_CACHE = {}
_WEIGHT_RE_KG = re.compile(r"(?i)\b(\d+(?:\.\d+)?)\s*kg\b")
_WEIGHT_RE_LB = re.compile(r"(?i)\b(\d+(?:\.\d+)?)\s*(?:lb|lbs|pounds?)\b")

def _ensure_vocab():
    global _TRUSTED_VOCAB
    if _TRUSTED_VOCAB is not None:
        return
    vocab = set()
    if _wf_top_n:
        try:
            for w in _wf_top_n("en", n_top=200000, wordlist="large"):
                if w and w.isalpha():
                    vocab.add(w.lower())
        except Exception:
            pass
    _TRUSTED_VOCAB = vocab

def _zipf(word):
    try:
        if _wf_zipf:
            return _wf_zipf(word, "en")
    except Exception:
        pass
    return 0.0

_SYMPTOM_TERMS = (
    "pain", "tenderness", "swelling", "soreness",
    "numbness", "tingling", "weakness", "redness", "itching", "burning", "cramps"
)
_BODY_WORD = r"(?:chest|head|neck|back|abdomen|abdominal|stomach|belly|throat|ear|eye|shoulder|arm|elbow|wrist|hand|finger|hip|knee|leg|ankle|foot|toe)"

def _fix_bodypart_noun_confusions(text: str) -> str:
    if not text:
        return text
    pat = re.compile(fr"(?i)\b({_BODY_WORD})\s+(patient|patients)\b")
    def repl(m):
        part = m.group(1)
        best, best_sc = "pain", _zipf(f"{part.lower()} pain")
        for term in _SYMPTOM_TERMS:
            sc = _zipf(f"{part.lower()} {term}")
            if sc > best_sc:
                best, best_sc = term, sc
        return f"{part} {best}"
    return pat.sub(repl, text)

_ACRO_REV_RE = re.compile(r'(?i)\b([A-Za-z][A-Za-z-]+(?:\s+[A-Za-z][A-Za-z-]+){0,7})\s*\(\s*([A-Z]{2,6})\s*\)')
_ACRO_FWD_RE = re.compile(r'\b([A-Z]{2,6})\s*\(\s*([^)]+?)\s*\)')

def _norm_space(s: str) -> str:
    return re.sub(r'\s+', ' ', (s or '').strip())

def _build_acronym_map_from_corpus(results, min_count: int = 2):
    texts = _corpus_texts(results)
    counts = defaultdict(lambda: defaultdict(int))
    for t in texts:
        for m in _ACRO_FWD_RE.finditer(t):
            acro = m.group(1).upper()
            exp  = _norm_space(m.group(2).lower())
            if 3 <= len(exp) <= 80:
                counts[acro][exp] += 1
        for m in _ACRO_REV_RE.finditer(t):
            exp  = _norm_space(m.group(1).lower())
            acro = m.group(2).upper()
            if 3 <= len(exp) <= 80:
                counts[acro][exp] += 1
    acro_map = {}
    for acro, bag in counts.items():
        exp, n = max(bag.items(), key=lambda kv: kv[1])
        if n >= min_count:
            acro_map[acro] = exp
    return acro_map

def _normalize_acronyms_in_text(text: str, acro_map: dict) -> str:
    if not text or not acro_map:
        return text
    def fix_rev(m):
        exp, acro = m.group(1), m.group(2).upper()
        canon = acro_map.get(acro)
        if not canon:
            return m.group(0)
        return f"{_case_like(exp, canon)} ({acro})"
    def fix_fwd(m):
        acro, exp = m.group(1).upper(), m.group(2)
        canon = acro_map.get(acro)
        if not canon:
            return m.group(0)
        return f"{acro} ({_case_like(exp, canon)})"
    text = _ACRO_REV_RE.sub(fix_rev, text)
    text = _ACRO_FWD_RE.sub(fix_fwd, text)
    return text

def _fix_medical_confusables_general(text: str) -> str:
    if not text:
        return text
    text = re.sub(r'(?i)\bmac\s*\(\s*maximum alveolar concentration\s*\)', 'MAC (minimum alveolar concentration)', text)
    text = re.sub(r'(?i)\bmaximum alveolar concentration\b(?=[^.)]*\bMAC\b)', 'minimum alveolar concentration', text)
    return text

_SEEDED_ACRO = {
    "MAC": "minimum alveolar concentration",
    "GCS": "glasgow coma scale",
    "COPD": "chronic obstructive pulmonary disease",
    "ARDS": "acute respiratory distress syndrome",
    "DVT": "deep vein thrombosis",
    "PE": "pulmonary embolism"
}

def _merge_acro_maps(seed: dict, learned: dict) -> dict:
    m = dict(seed)
    m.update(learned or {})
    return m

def _case_like(src, repl):
    if src.isupper():
        return repl.upper()
    if src[:1].isupper():
        return repl.capitalize()
    return repl

def _similarity(a, b):
    if _rf_fuzz2:
        return float(_rf_fuzz2.ratio(a, b))
    return difflib.SequenceMatcher(None, a, b).ratio() * 100.0

def _candidate_set(lw):
    _ensure_vocab()
    L = len(lw)
    cands = [w for w in _TRUSTED_VOCAB if w and w[0] == lw[0] and abs(len(w) - L) <= 2]
    if not cands:
        cands = [w for w in _TRUSTED_VOCAB if abs(len(w) - L) <= 2]
    return cands[:5000]

def _threshold_for(lw):
    L = len(lw)
    if L >= 8:
        return 66.0
    if L >= 6:
        return 68.0
    if L >= 4:
        return 72.0
    return 76.0

def _score_with_conf(lw, cand):
    s = _similarity(lw, cand)
    boost = max(0.0, _zipf(cand) - _zipf(lw)) * 4.0
    return s + boost

def _correct_token(tok):
    if not tok or not _word_re.fullmatch(tok):
        return tok
    lw = tok.lower()
    _ensure_vocab()
    if lw in _TRUSTED_VOCAB:
        return tok
    cands = _candidate_set(lw)
    if not cands:
        return tok
    best, best_conf = None, -1.0
    for c in cands:
        sc = _score_with_conf(lw, c)
        if sc > best_conf:
            best, best_conf = c, sc
    thr = _threshold_for(lw)
    if best and best_conf >= thr:
        return _case_like(tok, best)
    return tok

def _autocorrect_text(text):
    if not text:
        return text
    out, i = [], 0
    for m in _word_re.finditer(text):
        s, e = m.span()
        if s > i:
            out.append(text[i:s])
        token = text[s:e]
        if "-" in token and token.count("-") == 1:
            a, b = token.split("-")
            token = _correct_token(a) + "-" + _correct_token(b)
        else:
            token = _correct_token(token)
        out.append(token)
        i = e
    out.append(text[i:])
    return "".join(out)

def _wants_example(q: str) -> bool:
    if not q:
        return False
    return bool(re.search(r"(?i)\b(example|e\.g\.|for instance|sample calculation|worked example|with example|show.*example|give.*example)\b", q))

def _extract_dose_sentences(text: str):
    if not text:
        return []
    sents = re.split(r'(?<=[.!?])\s+', text)
    hits = []
    for s in sents:
        if re.search(r'(?i)\b(mg|mcg|µg|mg/kg|mcg/kg|units|iu)\b', s) and re.search(r'\d', s):
            hits.append(s.strip())
    return hits[:5]

def _parse_mg_per_kg(sentence: str):
    if not sentence:
        return None
    m = re.search(r'(?i)(\d+(?:\.\d+)?)\s*(?:–|-|to)\s*(\d+(?:\.\d+)?)\s*mg\s*/\s*kg', sentence)
    if m:
        try:
            lo = float(m.group(1)); hi = float(m.group(2))
            return (lo+hi)/2.0
        except Exception:
            pass
    m2 = re.search(r'(?i)(\d+(?:\.\d+)?)\s*mg\s*/\s*kg', sentence)
    if m2:
        try:
            return float(m2.group(1))
        except Exception:
            pass
    return None

def _build_example_line_from_page_text(page_text: str) -> str:
    dose_sents = _extract_dose_sentences(page_text)
    mgkg = None
    for s in dose_sents:
        mgkg = _parse_mg_per_kg(s)
        if mgkg is not None:
            break
    if mgkg is None:
        return ""
    if not (0.1 <= mgkg <= 15.0):
        return ""
    total = round(mgkg * 70, 1)
    return f"For a 70-kg adult at {mgkg:g} mg/kg, the calculated dose is {total:g} mg."

def _page_text_from_url(url):
    try:
        headers = {"User-Agent":"Mozilla/5.0"}
        rr = requests.get(url, headers=headers, timeout=15)
        if rr.status_code != 200:
            return ""
        soup = BeautifulSoup(rr.text, "lxml")
        for s in soup(["script","style","noscript","header","footer","nav"]):
            s.extract()
        return " ".join(soup.get_text("\n").split())
    except Exception:
        return ""

def _med_vocab_from_text(t):
    words = [w.lower() for w in _word_re.findall(t or "")]
    counts = {}
    for w in words:
        if len(w) >= 5:
            counts[w] = counts.get(w, 0) + 1
    base = {w for w,c in counts.items() if c >= 2}
    drug_like = {w for w in words if len(w) >= 5 and _HC_DRUG_SUFFIX_RE.search(w)}
    dose_near = {m.group(1).lower() for m in re.finditer(r"([A-Za-z][A-Za-z'-]{4,})\s+\d+(?:\.\d+)?\s*(?:mcg|µg|mg|g|iu|units?)\b", t or "", re.I)}
    return base | drug_like | dose_near

def _build_med_vocab(results, cap=5):
    vocab = set()
    for r in results:
        vocab |= _med_vocab_from_text((r.get("title","") or "") + " " + (r.get("body","") or ""))
    n = 0
    for r in results:
        u = r.get("url","")
        if not _is_credible(u):
            continue
        txt = _page_text_from_url(u)
        if not txt:
            continue
        vocab |= _med_vocab_from_text(txt)
        n += 1
        if n >= cap:
            break
    _ensure_vocab()
    return vocab

def _best_med_cand(lw, candidates):
    L = len(lw)
    pool = [w for w in candidates if w and w[0] == lw[0] and abs(len(w) - L) <= 3]
    if not pool:
        return None
    best, bsc = None, -1.0
    for c in pool:
        sc = _similarity(lw, c)
        if sc > bsc:
            best, bsc = c, sc
    thr = 64.0 if L >= 8 else 68.0
    if bsc >= thr:
        return best
    return None

def _spellfix_med_terms_in_answer(text: str, med_vocab):
    if not text:
        return text
    _ensure_vocab()
    base_known = _TRUSTED_VOCAB or set()
    out, i = [], 0
    for m in _word_re.finditer(text):
        s, e = m.span()
        if s > i:
            out.append(text[i:s])
        tok = text[s:e]
        lw = tok.lower()
        if lw not in base_known:
            cand = _best_med_cand(lw, med_vocab if med_vocab else base_known)
            if cand:
                tok = _case_like(tok, cand)
        out.append(tok)
        i = e
    out.append(text[i:])
    return "".join(out)

def _contextual_collocation_fix(text: str) -> str:
    if not text:
        return text
    pat = re.compile(r'(?i)\b([A-Za-z][A-Za-z\'-]*)\s+(or|and)\s+([A-Za-z][A-Za-z\'-]*)\b')
    def repl(m):
        a, conj, b = m.group(1), m.group(2), m.group(3)
        base = _zipf(f"{a.lower()} {conj.lower()} {b.lower()}")
        lw = b.lower()
        cands = _candidate_set(lw)
        if not cands:
            return m.group(0)
        ranked = sorted(cands, key=lambda c: -_score_with_conf(lw, c))[:8]
        best_word, best_score = b, base
        for c in ranked:
            s = _zipf(f"{a.lower()} {conj.lower()} {c}")
            if s > best_score + 0.8:
                best_word, best_score = c, s
        if best_word != b:
            return f"{a} {conj} {_case_like(b, best_word)}"
        return m.group(0)
    return pat.sub(repl, text)

def _collapse_redundant_phrases(text: str) -> str:
    if not text:
        return text
    t = re.sub(r'(?i)\b(symptoms?)\s+of\s+\1\s+of\b', r'\1 of', text)
    t = re.sub(r'(?i)\b(signs?)\s+of\s+\1\s+of\b', r'\1 of', t)
    t = re.sub(r'(?i)\b(diagnosis|treatment|management)\s+of\s+\1\s+of\b', r'\1 of', t)
    t = re.sub(r'(?i)\b(\w+)(?:\s*,\s*\1\b)+', r'\1', t)
    return t

def _apply_final_polish(text: str) -> str:
    t = _collapse_redundant_phrases(text)
    t = _contextual_collocation_fix(t)
    t = _dedupe_repeated_content(t)
    t = re.sub(r'(\n\s*){3,}', r'\n\n', t).strip()
    return t

def _enumerations_to_bullets(text: str) -> str:
    if not text:
        return text
    enum_pat = re.compile(r'(?<!\w)(\d{1,2})[.)]\s+')
    blocks = re.split(r'(?:\n\s*\n)+', text.strip())
    def should_bullet(s: str) -> bool:
        return ":" not in s
    new_blocks = []
    for b in blocks:
        if _is_list_block(b):
            items = _items_from_list(b)
            lines = [f"• {it.strip()}" if should_bullet(it) else it.strip() for it in items if it.strip()]
            new_blocks.append("\n".join(lines))
            continue
        if len(list(enum_pat.finditer(b))) >= 2:
            parts = []
            last_end = None
            first = True
            for m in enum_pat.finditer(b):
                if first:
                    last_end = m.end(); first = False
                else:
                    seg = b[last_end:m.start()]
                    parts.append(seg.strip(" \t;:-"))
                    last_end = m.end()
            tail = b[last_end:] if last_end is not None else ""
            if tail:
                parts.append(tail.strip(" \t;:-"))
            lines = [f"• {p}" if should_bullet(p) else p for p in parts if p]
            new_blocks.append("\n".join(lines) if lines else b)
            continue
        lines = []
        for ln in b.splitlines():
            m = _list_item_re.match(ln)
            if m:
                content = m.group(1).strip()
                lines.append(f"• {content}" if should_bullet(content) else content)
            else:
                lines.append(ln)
        new_blocks.append("\n".join(lines))
    return "\n\n".join(new_blocks).strip()

def _needs_dose_answer(q: str) -> bool:
    if not q:
        return False
    return bool(re.search(r'(?i)\b(dose|dosage|how much|mg/kg|milligram|tablet|syrup)\b', q))

def _dose_only_prompt(query: str, snippet_text: str) -> str:
    q = _pre(query)
    s = _pre(snippet_text or "")
    return (
        f"{s}\n\n"
        "You are a pediatric clinical pharmacist. Output exactly the recommended dose matched to the age in the question, including standard frequency and the usual maximum daily dose, plus common label side effects and a concise cautionary disclaimer. "
        "If dosing is weight-based, express it per dose as mg/kg and also provide the typical per-dose cap when relevant; never confuse mg/kg with total mg. "
        "If the child is ≤5 years old, neonate, or infant, include a strong caution that dosing must be clinician-directed, verify product strength (mg/mL), and use the supplied oral syringe; still provide the standard reference dose if one exists. "
        "If the medicine is contraindicated at the given age, write 'Dose: Do not use' and explain briefly in the disclaimer. "
        "Format strictly: Dose: <amount and unit> <frequency>; Max: <daily max if standard>; Side effects: <comma-separated>; Disclaimer: <short caution + general disclaimer>. End with <<<END>>>. If several pediatric bands exist, pick the band that includes the age. No extra sentences."
        f"\n\nQuestion: {q}\nAnswer:"
    )

def _tidy_dose_line(line: str) -> str:
    t = (line or "").strip()
    t = re.sub(r'^\s*(?:[-*•]\s+|\d{1,2}[.)]\s+)', '', t)
    if not re.match(r'(?i)^dose\s*:', t):
        t = "Dose: " + t
    if not re.search(r'[.?!]$', t):
        t += '.'
    t = re.sub(r'\s{2,}', ' ', t)
    return t.strip()

def _ensure_dose_present(ans: str, q: str, snippet_text: str) -> str:
    if _DOSE_PHRASE_RE.search(ans or ""):
        return _tidy_dose_line(ans)
    p = _dose_only_prompt(q, snippet_text)
    try:
        raw = generate(p, max_new_tokens=256, temperature=0.0)
    except TypeError:
        raw = generate(p)
    one = _safe_text(raw, q)
    one = _strip_role_artifacts(one)
    one = _cut_at_end_token(one).strip()
    if _DOSE_PHRASE_RE.search(one):
        return _tidy_dose_line(one)
    p2 = p + "\n\nOnly write the single line starting with 'Dose:' followed by units and frequency. Nothing else. <<<END>>>"
    try:
        raw2 = generate(p2, max_new_tokens=256, temperature=0.0)
    except TypeError:
        raw2 = generate(p2)
    one2 = _safe_text(raw2, q)
    one2 = _strip_role_artifacts(one2)
    one2 = _cut_at_end_token(one2).strip()
    return _tidy_dose_line(one2) if _DOSE_PHRASE_RE.search(one2) else ans

def _cut_at_end_token(text: str) -> str:
    if "<<<END>>>" in text:
        return text.split("<<<END>>>")[0].strip()
    return text

def _ensure_professional_overview(ans: str, q: str) -> str:
    lines = [ln for ln in (ans or "").splitlines() if ln.strip()]
    if lines and lines[0].lstrip().startswith("•"):
        topic = re.sub(r'^\s*(how to|steps? to|procedure for|management of)\s+', '', q or '', flags=re.I).strip().rstrip('?.')
        if re.search(r'(?i)\b(cpr|resuscitation|cardiac arrest|aed|bls)\b', q or ''):
            overview = "Cardiopulmonary resuscitation for an unresponsive person with no normal breathing prioritizes scene safety, rapid activation of emergency services, high-quality chest compressions, rescue breaths if trained, and early defibrillation with an AED."
        else:
            overview = f"This outlines the standard, safety-focused procedure for {topic if topic else 'the requested task'}, presented in a concise sequence for lay responders."
        return overview.strip() + "\n\n" + ans
    return ans

def _build_factual_example(query: str) -> str:
    queries = [
        query + " example",
        query + " dosing example",
        query + " mg/kg example",
        query + " site:nhs.uk",
        query + " site:fda.gov",
        query + " site:who.int",
        query + " site:nice.org.uk",
        query + " site:merckmanuals.com"
    ]
    for q in queries:
        res = duckduckgo_search(q)
        cred = [r for r in res if _is_credible(r.get("url",""))]
        pool = cred if cred else res
        for r in pool:
            url = r.get("url","")
            if not url:
                continue
            try:
                headers = {"User-Agent":"Mozilla/5.0"}
                rr = requests.get(url, headers=headers, timeout=20)
                if rr.status_code != 200:
                    continue
                soup = BeautifulSoup(rr.text, "lxml")
                for s in soup(["script","style","noscript","header","footer","nav"]):
                    s.extract()
                page_text = " ".join(soup.get_text("\n").split())
                line = _build_example_line_from_page_text(page_text)
                if line:
                    return line
            except Exception:
                continue
    return ""

_WEIGHT_RE_KG = re.compile(r"(?i)\b(\d+(?:\.\d+)?)\s*kg\b")
_WEIGHT_RE_LB = re.compile(r"(?i)\b(\d+(?:\.\d+)?)\s*(?:lb|lbs|pounds?)\b")
_QH_RE = re.compile(r"(?i)\bq\s*(\d{1,2})\s*(?:h|hr|hrs)\b")
_EVERY_H_RE = re.compile(r"(?i)\bevery\s+(\d{1,2})\s*(?:hours?|hrs?)\b")
_HR_RANGE_RE = re.compile(r"(?i)\b(\d{1,2})\s*[-–—]\s*(\d{1,2})\s*(?:hours?|hrs?)\b")
_MAX_DOSES_RE = re.compile(r"(?i)\bmax(?:imum)?\s*(?:of\s*)?(\d{1,2})\s*(?:doses?|times?)\s*(?:in|per)\s*24\s*hours?\b")
_MGKG_DAY_RE = re.compile(r"(?i)\b(\d+(?:\.\d+)?)\s*(?:[-–—]\s*(\d+(?:\.\d+)?))?\s*mg\s*/\s*kg\s*/\s*(?:day|24\s*hours?)\b")
_MGKG_DOSE_RE = re.compile(r"(?i)\b(\d+(?:\.\d+)?)\s*(?:[-–—]\s*(\d+(?:\.\d+)?))?\s*mg\s*/\s*kg(?!\s*/\s*day)\b")
_MG_PER_DOSE_RE = re.compile(r"(?i)\b(\d+(?:\.\d+)?)\s*(?:[-–—]\s*(\d+(?:\.\d+)?))?\s*mg\s*(?:per\s*(?:dose|dosing|administration)|each\s*dose)\b")
_MG_PER_DAY_RE = re.compile(r"(?i)\b(\d+(?:\.\d+)?)\s*(?:[-–—]\s*(\d+(?:\.\d+)?))?\s*mg\s*/\s*(?:day|24\s*hours?)\b")

def _detect_drug_from_query(q, med_vocab):
    best, best_sc = None, -1.0
    for tok in _word_re.findall(q or ""):
        lw = tok.lower()
        cand = _best_med_cand(lw, med_vocab or set())
        if cand:
            sc = _similarity(lw, cand)
            if sc > best_sc:
                best, best_sc = cand, sc
    return best

def _convert_months_over_12_to_years(text: str) -> str:
    def repl(m):
        val = float(m.group(1))
        if val > 12:
            years = val / 12.0
            y = f"{years:.2f}".rstrip('0').rstrip('.')
            return f"{y} years"
        return m.group(0)
    return re.sub(r'(?i)\b(\d+(?:\.\d+)?)\s*(?:months?|mos?|mths?|m/o)\b', repl, text)

def _intent_key(q, med_vocab):
    if not _needs_dose_answer(q or ""):
        return None
    t = (q or "")
    text = t.lower()
    drug = (_detect_drug_from_query(t, med_vocab) or "").strip().lower()
    age_years = None
    cmp_sig = "eq"
    m = re.search(r'(\d+(?:\.\d+)?)\s*(months?|mos?)\b', text)
    if m:
        age_months = float(m.group(1))
        age_years = round(age_months / 12.0, 2)
    else:
        m = (re.search(r'(\d+(?:\.\d+)?)\s*(years?|yrs?|yo|y/o)\b', text)
             or re.search(r'(\d+(?:\.\d+)?)\s*[- ]?year[- ]?old\b', text))
        if m:
            age_years = round(float(m.group(1)), 2)
        elif (re.search(r'\b(under|less\s*than|below)\s*(?:or\s*equal\s*to\s*)?(?:2|two)\s*(?:years?|yrs?)\b', text)
              or re.search(r'(?:≤|<=)\s*2\s*(?:years?|yrs?)\b', text)
              or re.search(r'(?:≤|<=)\s*24\s*months?\b', text)):
            age_years = 2.0
            cmp_sig = "le"
        else:
            m = re.search(r'\b(under|less\s*than|below)\s*(\d{1,3})\s*months?\b', text)
            if m:
                age_years = round(float(m.group(2)) / 12.0, 2)
                cmp_sig = "lt"
    kg = _WEIGHT_RE_KG.search(t)
    lb = _WEIGHT_RE_LB.search(t) if not kg else None
    if kg:
        w = f"wkg={kg.group(1)}"
    elif lb:
        w = f"wlb={lb.group(1)}"
    else:
        w = "w=?"
    age_sig = f"yr={age_years}" if age_years is not None else "yr=?"
    return f"dose|{drug}|age:{age_sig}|cmp:{cmp_sig}|{w}".lower()

def _round_step(x, step=0.5):
    try:
        return round(round(float(x)/step)*step, 2)
    except Exception:
        return x

def _parse_doses_per_day(text: str):
    max_doses = None
    mmax = _MAX_DOSES_RE.search(text or "")
    if mmax:
        try:
            max_doses = int(mmax.group(1))
        except Exception:
            pass
    qh = _QH_RE.search(text or "")
    if qh:
        try:
            n = int(qh.group(1))
            if n > 0:
                est = max(1, min(12, int(round(24/n))))
                return est, max_doses or est
        except Exception:
            pass
    every = _EVERY_H_RE.search(text or "")
    if every:
        try:
            n = int(every.group(1))
            if n > 0:
                est = max(1, min(12, int(round(24/n))))
                return est, max_doses or est
        except Exception:
            pass
    rg = _HR_RANGE_RE.search(text or "")
    if rg:
        try:
            a = int(rg.group(1)); b = int(rg.group(2))
            lo = min(a,b); hi = max(a,b)
            mid = (lo+hi)/2.0
            est = max(1, min(12, int(round(24/mid))))
            if max_doses:
                return est, max_doses
            return est, max(est, int(24/lo))
        except Exception:
            pass
    if max_doses:
        return max_doses, max_doses
    return None, None

def _pick_hours_from_text(text: str, doses_per_day: int):
    m = _QH_RE.search(text or "")
    if m:
        try:
            n = int(m.group(1))
            if n>0:
                return n
        except Exception:
            pass
    m2 = _EVERY_H_RE.search(text or "")
    if m2:
        try:
            n = int(m2.group(1))
            if n>0:
                return n
        except Exception:
            pass
    m3 = _HR_RANGE_RE.search(text or "")
    if m3:
        try:
            a = int(m3.group(1)); b = int(m3.group(2))
            return int(round((a+b)/2.0))
        except Exception:
            pass
    if doses_per_day:
        try:
            return int(round(24/float(doses_per_day)))
        except Exception:
            return None
    return None

def _avg_pair(g1, g2):
    if g1 and g2:
        try:
            return (float(g1)+float(g2))/2.0
        except Exception:
            return None
    try:
        return float(g1 or g2) if (g1 or g2) else None
    except Exception:
        return None

def _extract_first_avg(pattern, text):
    m = pattern.search(text or "")
    if not m:
        return None
    return _avg_pair(m.group(1), m.group(2))

def _corpus_texts(results, cap=5):
    texts = []
    for r in results:
        t = (r.get("title","") or "") + " " + (r.get("body","") or "")
        if t.strip():
            texts.append(t)
    n = 0
    for r in results:
        u = r.get("url","")
        if not _is_credible(u):
            continue
        pt = _page_text_from_url(u)
        if pt:
            texts.append(pt)
            n += 1
            if n >= cap:
                break
    return texts

def _extract_phrases_from_text(t, n_min=2, n_max=4):
    words = [w.lower() for w in _word_re.findall(t or "")]
    phrases = []
    for n in range(n_min, n_max+1):
        for i in range(0, max(0, len(words)-n+1)):
            chunk = words[i:i+n]
            if not any(len(x) >= 5 for x in chunk):
                continue
            phrases.append(" ".join(chunk))
    return phrases

def _build_med_phrase_set(results):
    texts = _corpus_texts(results)
    counts = defaultdict(int)
    for tx in texts:
        for ph in _extract_phrases_from_text(tx, 2, 4):
            counts[ph] += 1
    keep = {p for p,c in counts.items() if c >= 2 and len(p) >= 9}
    return keep

def _index_phrases_by_first(phrases):
    idx = defaultdict(list)
    for p in phrases:
        toks = [w for w in p.split() if w]
        if not toks:
            continue
        key = toks[0].lower()
        if len(toks) >= 2:
            key = key + " " + toks[1].lower()
        idx[key].append(p)
    return idx

def _best_phrase_match(candidate, idx):
    toks = [w for w in candidate.split() if w]
    if not toks:
        return None, -1.0
    key = toks[0].lower()
    if len(toks) >= 2:
        key = key + " " + toks[1].lower()
    pool = idx.get(key, [])
    best, best_sc = None, -1.0
    for ph in pool:
        if len(ph.split()) != len(toks):
            continue
        if _rf_fuzz2:
            sc = _rf_fuzz2.token_set_ratio(candidate, ph)
        else:
            sc = int(_similarity_ratio(candidate, ph) * 100)
        if sc > best_sc:
            best, best_sc = ph, sc
    return best, best_sc

def _correct_phrases_with_corpus(text, phrase_set):
    if not text or not phrase_set:
        return text
    idx = _index_phrases_by_first(phrase_set)
    cands = list(set(_extract_phrases_from_text(text, 2, 4)))
    cands.sort(key=lambda s: -len(s))
    replaced = {}
    for cand in cands:
        if cand in phrase_set:
            continue
        match, score = _best_phrase_match(cand, idx)
        if match and score >= 88 and match != cand:
            replaced[cand] = match
    if not replaced:
        return text
    tokens = list(_word_re.finditer(text))
    if not tokens:
        return text
    low_words = [m.group(0).lower() for m in tokens]
    positions = [(m.start(), m.end()) for m in tokens]
    to_replace = []
    for cand, repl in replaced.items():
        n = len(cand.split())
        for i0 in range(0, len(low_words) - n + 1):
            seg = " ".join(low_words[i0:i0 + n])
            if seg == cand:
                s = positions[i0][0]
                e = positions[i0 + n - 1][1]
                to_replace.append((s, e, repl))
    if not to_replace:
        return text
    out = []
    cur = 0
    for s, e, repl in sorted(to_replace):
        out.append(text[cur:s])
        out.append(repl)
        cur = e
    out.append(text[cur:])
    return "".join(out)

_PREPOSITIONS = {"during","before","after","while","within","without","between","among","under","over","by","with","at","in","on","into","onto","from","through","toward","towards","upon","inside","outside","beneath","above","below","near","beside","around","beyond","against","until","since","past","per","via"}

_SEED_COLLOCATIONS = [
    ("eat","drink"),
    ("food","drink"),
    ("food","fluids"),
    ("fluids","water"),
    ("nausea","vomiting"),
    ("signs","symptoms"),
    ("risks","benefits"),
    ("benefits","risks"),
    ("fever","chills"),
    ("sprains","strains"),
    ("sprain","strain"),
    ("swelling","redness"),
    ("redness","swelling"),
    ("indications","contraindications"),
    ("contraindications","precautions"),
    ("ice","heat")
]

def _learn_collocations_from_corpus(results, min_count: int = 2, max_partners: int = 4):
    texts = _corpus_texts(results)
    pair_counts = defaultdict(lambda: defaultdict(int))
    pat = re.compile(r'(?i)\b([A-Za-z][A-Za-z\'-]{2,})\s+(and|or)\s+([A-Za-z][A-Za-z\'-]{2,})\b')
    for t in texts:
        for m in pat.finditer(t):
            a = m.group(1).lower()
            b = m.group(3).lower()
            pair_counts[a][b] += 1
            pair_counts[b][a] += 1
    learned = {}
    for a, bag in pair_counts.items():
        partners = [p for p, c in sorted(bag.items(), key=lambda kv: -kv[1]) if c >= min_count][:max_partners]
        if partners:
            learned[a] = set(partners)
    return learned

def _build_colloc_partner_map(seed_pairs, learned_map):
    partners = defaultdict(set)
    for a, b in seed_pairs:
        partners[a].add(b)
        partners[b].add(a)
    for a, bs in (learned_map or {}).items():
        for b in bs:
            partners[a].add(b)
    return {k: set(v) for k, v in partners.items()}

def _fix_coordination_collocations(text: str, colloc_partners: dict) -> str:
    if not text:
        return text
    if not colloc_partners:
        return text
    pat = re.compile(r'(?i)\b([A-Za-z][A-Za-z\'-]{2,})\s+(and|or)\s+([A-Za-z][A-Za-z\'-]{2,})\b')
    def choose(anchor_word, partner_word, orig_partner):
        a = anchor_word.lower()
        y = partner_word.lower()
        allowed = colloc_partners.get(a)
        if not allowed or y in allowed:
            return orig_partner
        best, best_sc = None, -1.0
        for cand in allowed:
            sc = _similarity(y, cand)
            if sc > best_sc:
                best, best_sc = cand, sc
        if y in _PREPOSITIONS and "drink" in allowed:
            return _case_like(orig_partner, "drink")
        if best and best_sc >= 74.0:
            return _case_like(orig_partner, best)
        return orig_partner
    def repl(m):
        anchor, conj, partner = m.group(1), m.group(2), m.group(3)
        fixed_partner = choose(anchor, partner, partner)
        if fixed_partner == partner:
            return m.group(0)
        return f"{anchor} {conj} {fixed_partner}"
    return pat.sub(repl, text)

_NUM_UNIT_RE = re.compile(r'(?i)\b\d+(?:\.\d+)?\s*(?:mg|mcg|µg|g|iu|units?|mL|ml|L|mg/kg|mcg/kg|bpm|mmHg|%|°C|°F)\b')

def _extract_num_units(text: str):
    from collections import Counter
    return Counter(_NUM_UNIT_RE.findall(text or ""))

def _capitalize_sentence_starts(text: str) -> str:
    if not text:
        return text
    def repl(m):
        return f"{m.group(1)}{m.group(2)}{m.group(3).upper()}"
    return re.sub(r'(^|\n|(?<=[.?!]))(\s*)([a-z])', repl, text)

_GRAMMAR_META_RE = re.compile(
    r"(?i)\b("
    r"the\s+(?:original\s+)?text\s+was\s+already\s+(?:grammatically\s+)?correct"
    r"|grammar\s+(?:is|was)\s+already\s+correct"
    r"|no\s+changes\s+were\s+needed"
    r"|no\s+edits?\s+required"
    r"|the\s+sentence[s]?\s+(?:is|are)\s+fine\s+as\s+is"
    r"|the\s+text\s+is\s+clear\s+and\s+correct"
    r")\b"
)

def _strip_grammar_meta_comments(text: str) -> str:
    if not text:
        return text
    sentences = re.split(r'(?<=[.!?])\s+', text.strip())
    kept = [s for s in sentences if not _GRAMMAR_META_RE.search(s)]
    return " ".join(kept).strip()

def _fix_unmatched_parentheses_general(text: str) -> str:
    if not text:
        return text
    t = text
    t = re.sub(r'\(([^()]*)\s*([.!?])(?!\))', r'(\1)\2', t)
    t = re.sub(r'\(([^()]*)$', r'(\1)', t, flags=re.M)
    opens = t.count('('); closes = t.count(')')
    if opens > closes:
        t = t + (')' * (opens - closes))
    return t

def _smart_sentence_case(text: str) -> str:
    if not text:
        return text
    pat = re.compile(r'(^|(?<=[.!?]\s))([\'"“”(\[]*\s*)([a-z])')
    return pat.sub(lambda m: f"{m.group(1)}{m.group(2)}{m.group(3).upper()}", text)

def _preserve_acronyms_case(text: str) -> str:
    if not text:
        return text
    t = text
    t = re.sub(r'(?i)\bmmhg\b', 'mmHg', t)
    for ac in ["CPR","AED","ECG","EKG","CT","MRI","ICU","ED","BPH","PDE5","BP","HR","RR","SpO2","O2"]:
        t = re.sub(rf'(?i)\b{ac}\b', ac, t)
    return t

def _drop_the_before_mass_nouns(text: str) -> str:
    if not text:
        return text
    mass = r'(aspirin|paracetamol|acetaminophen|ibuprofen|naproxen|nitroglycerin|insulin|oxygen|water|glucose|caffeine|morphine|adrenaline|epinephrine)'
    blockers = r'(tablet|tablets|capsule|capsules|dose|doses|solution|spray|patch|sublingual|tab|cap)'
    return re.sub(rf'(?i)\bthe\s+{mass}\b(?!\s+{blockers})', lambda m: m.group(0)[4:], text)

def _one_off_grammar_sanitize(text: str) -> str:
    if not text:
        return text
    t = text
    t = re.sub(r'(?im)^\s*no\s+steps,?\s*please\.?\s*', ' ', t)
    t = re.sub(r'(?is)^(?:\s*["“”\'’]*)?(?:write|provide)\s+a\s+concise[^.!\n]*[.!?]\s*', ' ', t)
    t = re.sub(r'(?i)\bforor\b', 'or', t)
    t = re.sub(r'(?i)\bandand\b', 'and', t)
    t = re.sub(r'(?i)\bthethe\b', 'the', t)
    t = re.sub(r'(?i)\bofof\b', 'of', t)
    t = re.sub(r'\b([A-Za-z]+)(?:\s+\1\b)+', r'\1', t, flags=re.I)
    t = re.sub(r'(\d)\s*/\s*(\d)', r'\1/\2', t)
    t = re.sub(r'\s+([,.;:!?])', r'\1', t)
    t = re.sub(r'([,;:])(?!\s)', r'\1 ', t)
    t = re.sub(r'([.!?])([A-Za-z])', r'\1 \2', t)
    t = re.sub(r'([.!?,;:])\1+', r'\1', t)
    t = re.sub(r'\(\s+\)', '', t)
    t = re.sub(r'\(\s+([^\)]+)\s+\)', r'(\1)', t)
    t = re.sub(r'(?i)\bhealthy professional\b', 'healthcare professional', t)
    t = _drop_the_before_mass_nouns(t)
    t = _fix_unmatched_parentheses_general(t)
    t = _preserve_acronyms_case(t)
    t = _smart_sentence_case(t)
    t = re.sub(r'(?i)\bmmhg\b', 'mmHg', t)
    t = re.sub(r'\s{2,}', ' ', t).strip()
    return t

def _proofread_with_model(text: str) -> str:
    if not text:
        return text
    prompt = (
        "You are a meticulous medical copy editor.\n"
        "Rewrite the text so that grammar, sentence structure, capitalization, and agreement are correct.\n"
        "Keep meaning, facts, acronyms, dosages, numbers, and units EXACTLY the same.\n"
        "Do not add or remove information. Do not include explanations or meta-comments.\n"
        "Return only the corrected text.\n\n"
        f"Text:\n{text}\n\nCorrected:"
    )
    try:
        raw = generate(prompt, max_new_tokens=2048, temperature=0.0)
    except TypeError:
        raw = generate(prompt)
    out = _safe_text(raw, text)
    out = _strip_meta_overview_speak(out)
    out = _one_off_grammar_sanitize(out)
    return out

def _final_grammar_pass(text: str) -> str:
    if not text:
        return text
    before = _extract_num_units(text)
    edited = _proofread_with_model(text)
    if not edited:
        return text
    edited = _strip_grammar_meta_comments(edited)
    edited = _one_off_grammar_sanitize(edited)
    if not edited.strip():
        return text
    after = _extract_num_units(edited)
    if before != after:
        fallback = _one_off_grammar_sanitize(text)
        return fallback if fallback.strip() else text
    return edited

def _strip_or_fragment_sentences(text: str) -> str:
    if not text:
        return text
    parts = re.split(r'(?<=[.!?])\s+|\n+', text.strip())
    kept = []
    for s in parts:
        st = s.strip()
        if not st:
            continue
        start = re.sub(r'^[\s"\'“”\(\)\[\]\-–—•*]+', '', st)
        if re.match(r'(?i)^or(?:\b|[,:\-–—\s])', start):
            continue
        kept.append(st)
    sep = '\n' if '\n' in text else ' '
    return sep.join(kept)

_MONTH_AGE_ANY_RE = re.compile(
    r'''(?ix)
    \b(
        \d+(?:\.\d+)?\s*(?:months?|mos?|mths?|m/o)\b(?:\s*old|\s*y/o|\s*yo)? |
        \d+\s*[-\s]?(?:month|mo)s?\s*[-\s]?old
    )\b
    '''
)

_CONTEXT_REQ_RE = re.compile(
    r'(?im)^(?:please|kindly|could you|can you|would you)\b.*\b(context|details|age(?: group)?|location|scenario|more information)\b.*$'
)
_SECTION_LABEL_RE = re.compile(
    r'(?im)^(adult|child(?:ren)?|pediatric(?:s)?|infant|neonate|adolescent|elderly|geriatr(?:ic|ics)|pregnant|male|female)\s*:?\s*$'
)
def _strip_context_prompts_and_labels(text: str) -> str:
    if not text:
        return text
    lines = []
    for ln in text.splitlines():
        s = ln.strip()
        if not s:
            lines.append(ln)
            continue
        if _CONTEXT_REQ_RE.match(s):
            continue
        if _SECTION_LABEL_RE.match(s):
            continue
        lines.append(ln)
    out = "\n".join(lines).strip()
    out = re.sub(r'(?i)^\s*(please|kindly)\s+(?:provide|share|give)\s+(?:more\s+)?(?:context|details|information)[^.?!]*[.?!]\s*', '', out, count=1)
    return out

def format_for_doctorvit(text: str) -> str:
    """
    Convert model text into clean HTML using .dv-card/.dv-sec styles.
    - Strips <<<END>>> and any [CONTEXT — DO NOT ECHO] blocks
    - Detects headings ("Title:" or standalone Title Case lines)
    - Renders bullets (•, -, *, numbered) as <ul><li>…</li></ul>
    - Everything else becomes paragraphs
    """
    import re, html

    SENTINEL = "<<<END>>>"
    HEAD_COLON_RE = re.compile(r'^\s*([A-Z][A-Za-z0-9 /&\-\(\)]+?)\s*:\s*$')
    HEAD_TITLE_RE = re.compile(r'^\s*([A-Z][A-Za-z0-9 /&\-\(\)]+)\s*$')  # no trailing punctuation
    BULLET_RE     = re.compile(r'^\s*(?:[-*•·‣▪◦]|(?:\d+)[\.\)])\s+(.*)$', re.U)

    # --- Clean/pass 1 ---
    t = text if isinstance(text, str) else str(text or "")
    t = t.split(SENTINEL, 1)[0]
    t = re.sub(r'\[CONTEXT — DO NOT ECHO\].*?\[/CONTEXT\]', '', t, flags=re.S)
    t = t.replace("\r\n", "\n").replace("\r", "\n")
    t = re.sub(r'\n{3,}', '\n\n', t)                    # collapse blank lines
    t = re.sub(r'^[•·‣▪◦]\s*', '- ', t, flags=re.M)     # normalize bullet glyphs
    t = t.strip()

    if not t:
        return '<div class="dv-card"><div class="dv-sec"><p>Unknown</p></div></div>'

    lines = [ln.strip() for ln in t.splitlines()]
    parts, in_section, in_list = ['<div class="dv-card">'], False, False

    def close_list():
        nonlocal in_list
        if in_list:
            parts.append('</ul>')
            in_list = False

    def close_section():
        nonlocal in_section
        if in_section:
            close_list()
            parts.append('</div>')
            in_section = False

    def open_section(title: str):
        nonlocal in_section
        close_section()
        parts.append(f'<div class="dv-sec"><h3>{html.escape(title)}</h3>')
        in_section = True

    i = 0
    while i < len(lines):
        ln = lines[i]
        if not ln:
            close_list()
            i += 1
            continue

        # Headings: "Title:" or a short title-case line without punctuation
        m = HEAD_COLON_RE.match(ln) or (
            len(ln) < 80 and not re.search(r'[.:;!?]$', ln) and HEAD_TITLE_RE.match(ln)
        )
        if m:
            open_section(m.group(1).strip(' -–—'))
            i += 1
            continue

        # Bullets (symbols or numbered)
        b = BULLET_RE.match(ln)
        if b:
            if not in_section:
                open_section("Details")
            if not in_list:
                parts.append('<ul>')
                in_list = True
            parts.append(f'<li>{html.escape(b.group(1).strip())}</li>')
            i += 1
            continue

        # Paragraph
        if not in_section:
            open_section("Details")
        close_list()
        parts.append(f'<p>{html.escape(ln)}</p>')
        i += 1

    close_section()
    parts.append('</div>')
    return ''.join(parts)


def respond_stream(query):
    q_in = (query or "").strip()
    q = _autocorrect_text(q_in)

    # Early safety/age guards
    if _needs_dose_answer(q) and _MONTH_AGE_ANY_RE.search(q):
        yield format_for_doctorvit(
            "For safety and consistency, please provide age in years (e.g., 0.5 years instead of 6 months). "
            "Dosing queries using months are not accepted."
        )
        return
    if _needs_dose_answer(q):
        q = _convert_months_over_12_to_years(q)
    if _needs_dose_answer(q) and _age_is_two_or_under(q):
        yield format_for_doctorvit(
            "Caution (≤2 years): Dosing and administration should be directed by a clinician. "
            "Use the supplied oral syringe, verify product strength (mg/mL), and avoid self-dosing without professional advice."
        )
        return
    if not q:
        q = "General health guidance"

    # Streaming placeholder
    yield "<div style='font-family: system-ui; color:#6b7280; font-size:14px;'>Thinking…</div>"

    try:
        # Lightweight retrieval to build snippet/context
        search_query = q + " dosing guidance" if re.search(r'(?i)\bdose|dosage|dosing|calculate', q) else q
        results = duckduckgo_search(search_query)
        snippet = select_snippet(q, results)
        snippet_text = (snippet.get('body', '') or '').strip()

        # Lexical helpers
        med_vocab = _build_med_vocab(results)
        med_phrases = _build_med_phrase_set(results)
        acro_map = _merge_acro_maps(_SEEDED_ACRO, _build_acronym_map_from_corpus(results, min_count=1))
        learned_collocs = _learn_collocations_from_corpus(results, min_count=2, max_partners=4)
        colloc_partners = _build_colloc_partner_map(_SEED_COLLOCATIONS, learned_collocs)

        cache_key = _intent_key(q, med_vocab)
        if cache_key and cache_key in INTENT_CACHE:
            yield INTENT_CACHE[cache_key]
            return

        prompt = guard_and_build_prompt(q, snippet_text)

        # Safety/scoping branches
        if prompt == "SELF_HARM_SUPPORT":
            out = _self_harm_support_response(q)
            out = _fix_bodypart_noun_confusions(out)
            out = _normalize_acronyms_in_text(out, acro_map)
            out = _fix_coordination_collocations(out, colloc_partners)
            out = _fix_medical_confusables_general(out)
            out = _strip_context_prompts_and_labels(out)
            out = _final_grammar_pass(out)
            out_html = format_for_doctorvit(out)
            if cache_key:
                INTENT_CACHE[cache_key] = out_html
            yield out_html
            return

        if prompt == "Please ask only healthcare question.":
            out_html = format_for_doctorvit("Please ask only healthcare question.")
            if cache_key:
                INTENT_CACHE[cache_key] = out_html
            yield out_html
            return

        # Primary generation
        try:
            raw = generate(prompt, max_new_tokens=2048, temperature=0.0)
        except TypeError:
            raw = generate(prompt)

        # Fallback if model drifted into code/NLP explanations
        if _looks_like_code_explanation(raw) or _looks_like_nlp_explanation(raw):
            repair_prompt = _repair_med_prompt(q, snippet_text)
            try:
                raw = generate(repair_prompt, max_new_tokens=2048, temperature=0.0)
            except TypeError:
                raw = generate(repair_prompt)

        # Post-process pass 1
        final_text = _safe_text(raw, q)
        final_text = _filter_age_mismatch(final_text, q)
        final_text = dose_verification_filter(final_text)
        final_text = _strip_sentence_initial_yes(final_text)
        final_text = _strip_meta_overview_speak(final_text)
        final_text = _correct_phrases_with_corpus(final_text, med_phrases)
        if _needs_dose_answer(q):
            final_text = _ensure_dose_present(final_text, q, snippet_text)

        # If empty, repair path
        if not final_text.strip():
            repair_prompt = _repair_med_prompt(q, snippet_text)
            try:
                raw2 = generate(repair_prompt, max_new_tokens=2048, temperature=0.0)
            except TypeError:
                raw2 = generate(repair_prompt)
            ans2 = _safe_text(raw2, q)
            ans2 = _filter_age_mismatch(ans2, q)
            ans2 = dose_verification_filter(ans2)
            ans2 = _strip_sentence_initial_yes(ans2)
            ans2 = _strip_role_artifacts(ans2)
            ans2 = _normalize_numbered_steps(ans2)
            ans2 = _enumerations_to_bullets(ans2)
            ans2 = _strip_inline_enumerators(ans2)
            ans2 = _organize_paragraphs(ans2)
            ans2 = _strip_meta_overview_speak(ans2)
            ans2 = _correct_phrases_with_corpus(ans2, med_phrases)
            ans2 = _fix_bodypart_noun_confusions(ans2)
            ans2 = _normalize_acronyms_in_text(ans2, acro_map)
            ans2 = _fix_coordination_collocations(ans2, colloc_partners)
            ans2 = _fix_medical_confusables_general(ans2)
            if _needs_dose_answer(q):
                ans2 = _ensure_dose_present(ans2, q, snippet_text)
            ans2 = _apply_general_safety_overrides(ans2, q)
            ans2 = _apply_final_polish(ans2)
            ans2 = _strip_or_fragment_sentences(ans2)
            ans2 = _strip_context_prompts_and_labels(ans2)
            ans2 = _final_grammar_pass(ans2)
            ans2 = _spellfix_med_terms_in_answer(ans2, med_vocab)
            ans2 = _ensure_professional_overview(ans2, q)
            if _wants_example(q):
                fx = _build_factual_example(q)
                if fx:
                    ans2 = ans2 + ("\n\n" + fx)

            combined = ans2
            combined = _fix_bodypart_noun_confusions(combined)
            combined = _normalize_acronyms_in_text(combined, acro_map)
            combined = _fix_coordination_collocations(combined, colloc_partners)
            combined = _fix_medical_confusables_general(combined)
            combined = _strip_or_fragment_sentences(combined)
            combined = _strip_context_prompts_and_labels(combined)
            combined = _final_grammar_pass(combined)

            out_html = format_for_doctorvit(combined)
            if cache_key:
                INTENT_CACHE[cache_key] = out_html
            yield out_html
            return

        # Post-process pass 2 (normal path)
        final_text = _strip_role_artifacts(final_text)
        final_text = _normalize_numbered_steps(final_text)
        final_text = _enumerations_to_bullets(final_text)
        final_text = _strip_inline_enumerators(final_text)
        final_text = _organize_paragraphs(final_text)
        final_text = _fix_bodypart_noun_confusions(final_text)
        final_text = _normalize_acronyms_in_text(final_text, acro_map)
        final_text = _fix_coordination_collocations(final_text, colloc_partners)
        final_text = _fix_medical_confusables_general(final_text)
        final_text = _apply_general_safety_overrides(final_text, q)
        final_text = _strip_or_fragment_sentences(final_text)
        final_text = _strip_context_prompts_and_labels(final_text)
        final_text = _final_grammar_pass(final_text)
        final_text = _apply_final_polish(final_text)
        final_text = _spellfix_med_terms_in_answer(final_text, med_vocab)
        final_text = _ensure_professional_overview(final_text, q)
        if _wants_example(q):
            fx = _build_factual_example(q)
            if fx:
                final_text = final_text + "\n\n" + fx

        final_text = _fix_bodypart_noun_confusions(final_text)
        final_text = _normalize_acronyms_in_text(final_text, acro_map)
        final_text = _fix_coordination_collocations(final_text, colloc_partners)
        final_text = _fix_medical_confusables_general(final_text)
        final_text = _strip_or_fragment_sentences(final_text)
        final_text = _strip_meta_overview_speak(final_text)
        final_text = _strip_context_prompts_and_labels(final_text)
        final_text = _final_grammar_pass(final_text)

        out_html = format_for_doctorvit(final_text)
        if cache_key:
            INTENT_CACHE[cache_key] = out_html
        yield out_html

    except Exception:
        err = traceback.format_exc()
        yield format_for_doctorvit("An error occurred while generating the answer.\n" + err)

# %%
import gradio as gr
import html

with gr.Blocks(
    title=TITLE,
    css="""
#doctorvit .gradio-container {max-width: 980px !important;}
#doctorvit .gr-button {height: 48px; border-radius: 12px;}
#doctorvit p {margin: .75rem 0;}

#doctorvit .dv-card{background:#fff;border:1px solid #e5e7eb;border-radius:14px;padding:18px 20px;box-shadow:0 1px 2px rgba(0,0,0,.04)}
#doctorvit .dv-sec + .dv-sec{margin-top:10px}
#doctorvit .dv-sec h3{margin:10px 0 6px;font-size:17px;font-weight:700;color:#0f172a}
#doctorvit .dv-sec p{margin:6px 0;line-height:1.6;color:#0f172a}
#doctorvit .dv-sec ul{margin:6px 0 0 20px; list-style: disc; padding-left: 1.25rem;}
#doctorvit .dv-sec li{margin:4px 0}
"""
) as demo:

    # Wrap EVERYTHING so CSS applies to the output HTML too
    with gr.Column(elem_id="doctorvit"):
        try:
            if 'model' in globals():
                wiring_text = validate_activation_wiring(model)["summary"]
            else:
                wiring_text = "Model not loaded yet — activation wiring summary unavailable."
        except Exception as e:
            wiring_text = f"Wiring check failed: {type(e).__name__}: {e}"

        gr.HTML(f"""
        <div style="font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto; margin:8px 0 10px 0;">
            <div style="font-size:22px; font-weight:500; margin:0;">{html.escape(TITLE)}</div>
            <div style="color:#475569; margin-top:2px; font-weight:400;">{html.escape(DESC)}</div>
            <div style="margin-top:10px; padding:10px 12px; background:#f8fafc; color:#0f172a; border:1px solid #e5e7eb; border-radius:12px;">
                {html.escape(wiring_text)}
            </div>
        </div>
        """)

        with gr.Row():
            query = gr.Textbox(
                label="Ask your question",
                placeholder="Ask only healthcare question…",
                lines=3,
                autofocus=True
            )

        with gr.Row():
            go = gr.Button("Generate", variant="primary")
            clr = gr.Button("Clear")

        out = gr.HTML(label="Answer")

        # respond_stream already returns formatted HTML
        go.click(fn=respond_stream, inputs=[query], outputs=out)
        query.submit(fn=respond_stream, inputs=[query], outputs=out)

        def _clear():
            return gr.update(value=""), gr.update(value="")
        clr.click(_clear, inputs=None, outputs=[query, out])

port = _pick_port(7860, 30)
_free_port(port)
demo.queue()
demo.launch(server_name="0.0.0.0", server_port=port, share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://97cd964d1766bd7d4c.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://97cd964d1766bd7d4c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
